# %% [markdown]
# # Projeto 10: Regressão venda de vídeo games

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import pandas as pd
import torch
from torch import nn, optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import seaborn as sns
torch.__version__
# Out:
# '1.13.1+cu116'

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
torch.manual_seed(123)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base = pd.read_csv('/content/drive/MyDrive/Deep Learing de A à Z com PyTorch/Bases/games.csv')

# %%
base.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
base.shape
# Out:
# (16719, 16)

# %%
base = base.drop('Other_Sales', axis = 1)
base = base.drop('Global_Sales', axis = 1)
base = base.drop('Developer', axis = 1)

# %%
base.shape
# Out:
# (16719, 13)

# %%
sns.heatmap(base.isnull());

# %%
base = base.dropna(axis = 0)

# %%
sns.heatmap(base.isnull());

# %%
base.shape
# Out:
# (6825, 13)

# %%
base.loc[base['NA_Sales'] > 1]
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 6              New Super Mario Bros.       DS           2006.0      Platform
# 7                           Wii Play      Wii           2006.0          Misc
# ...                              ...      ...              ...           ...
# 1872                NCAA Football 14     X360           2013.0        Sports
# 1877                         NFL 2K1       DC           2000.0        Sports
# 1881                 Madden NFL 2004       XB           2003.0        Sports
# 1889                NCAA Football 13     X360           2012.0        Action
# 1953  Diablo II: Lord of Destruction       PC           2001.0  Role-Playing
#
#             Publisher  NA_Sales  EU_Sales  JP_Sales  Critic_Score  \
# 0            Nintendo     41.36     28.96      3.77          76.0
# 2            Nintendo     15.68     12.76      3.79          82.0
# 3            Nintendo     15.61     10.93      3.28          80.0
# 6            Nintendo     11.28      9.14      6.50          89.0
# 7            Nintendo     13.96      9.18      2.93          58.0
# ...               ...       ...       ...       ...           ...
# 1872  Electronic Arts      1.01      0.00      0.00          77.0
# 1877             Sega      1.02      0.05      0.00          97.0
# 1881  Electronic Arts      1.02      0.02      0.00          92.0
# 1889  Electronic Arts      1.02      0.00      0.00          76.0
# 1953    Vivendi Games      1.03      0.02      0.00          87.0
#
#       Critic_Count User_Score  User_Count Rating
# 0             51.0          8       322.0      E
# 2             73.0        8.3       709.0      E
# 3             73.0          8       192.0      E
# 6             65.0        8.5       431.0      E
# 7             41.0        6.6       129.0      E
# ...            ...        ...         ...    ...
# 1872          18.0        5.8        74.0      E
# 1877          22.0          6        47.0      E
# 1881          27.0        8.3        48.0      E
# 1889          20.0        5.5        65.0      E
# 1953          21.0        9.1       639.0      M
#
# [584 rows x 13 columns]

# %%
base = base.loc[base['NA_Sales'] > 1]

# %%
base.shape
# Out:
# (584, 13)

# %%
base.loc[base['EU_Sales'] > 1]
# Out:
#                            Name Platform  Year_of_Release       Genre  \
# 0                    Wii Sports      Wii           2006.0      Sports
# 2                Mario Kart Wii      Wii           2008.0      Racing
# 3             Wii Sports Resort      Wii           2009.0      Sports
# 6         New Super Mario Bros.       DS           2006.0    Platform
# 7                      Wii Play      Wii           2006.0        Misc
# ..                          ...      ...              ...         ...
# 568              Medal of Honor       PS           1998.0     Shooter
# 573  Tom Clancy's Splinter Cell      PS2           2003.0      Action
# 591      Mario Strikers Charged      Wii           2007.0      Sports
# 610                  Crazy Taxi      PS2           2001.0      Racing
# 636       The Sims: Bustin' Out      PS2           2003.0  Simulation
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Critic_Score  \
# 0                 Nintendo     41.36     28.96      3.77          76.0
# 2                 Nintendo     15.68     12.76      3.79          82.0
# 3                 Nintendo     15.61     10.93      3.28          80.0
# 6                 Nintendo     11.28      9.14      6.50          89.0
# 7                 Nintendo     13.96      9.18      2.93          58.0
# ..                     ...       ...       ...       ...           ...
# 568        Electronic Arts      1.44      1.09      0.00          92.0
# 573                Ubisoft      1.15      1.11      0.00          89.0
# 591               Nintendo      1.05      1.05      0.24          79.0
# 610  Acclaim Entertainment      1.13      1.12      0.06          80.0
# 636        Electronic Arts      1.07      1.19      0.00          81.0
#
#      Critic_Count User_Score  User_Count Rating
# 0            51.0          8       322.0      E
# 2            73.0        8.3       709.0      E
# 3            73.0          8       192.0      E
# 6            65.0        8.5       431.0      E
# 7            41.0        6.6       129.0      E
# ..            ...        ...         ...    ...
# 568          17.0        8.6        80.0      T
# 573          24.0        7.7       102.0      T
# 591          47.0          8       124.0   E10+
# 610          15.0        7.9        46.0      T
# 636          26.0        8.4        42.0      T
#
# [258 rows x 13 columns]

# %%
base = base.loc[base['EU_Sales'] > 1]

# %%
base.shape
# Out:
# (258, 13)

# %%
base['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                      Wii Sports
# 2                  Mario Kart Wii
# 3               Wii Sports Resort
# 6           New Super Mario Bros.
# 7                        Wii Play
#                   ...
# 568                Medal of Honor
# 573    Tom Clancy's Splinter Cell
# 591        Mario Strikers Charged
# 610                    Crazy Taxi
# 636         The Sims: Bustin' Out
# Name: Name, Length: 258, dtype: object>

# %%
base = base.drop('Name', axis = 1)

# %%
base.shape
# Out:
# (258, 12)

# %%
previsores = base.iloc[:, [0, 1, 2, 3, 7, 8, 9, 10, 11]].values
vendas = base.iloc[:, 4:7].values

# %%
previsores
# Out:
# array([['Wii', 2006.0, 'Sports', ..., '8', 322.0, 'E'],
#        ['Wii', 2008.0, 'Racing', ..., '8.3', 709.0, 'E'],
#        ['Wii', 2009.0, 'Sports', ..., '8', 192.0, 'E'],
#        ...,
#        ['Wii', 2007.0, 'Sports', ..., '8', 124.0, 'E10+'],
#        ['PS2', 2001.0, 'Racing', ..., '7.9', 46.0, 'T'],
#        ['PS2', 2003.0, 'Simulation', ..., '8.4', 42.0, 'T']], dtype=object)

# %%
vendas
# Out:
# array([[4.136e+01, 2.896e+01, 3.770e+00],
#        [1.568e+01, 1.276e+01, 3.790e+00],
#        [1.561e+01, 1.093e+01, 3.280e+00],
#        [1.128e+01, 9.140e+00, 6.500e+00],
#        [1.396e+01, 9.180e+00, 2.930e+00],
#        [1.444e+01, 6.940e+00, 4.700e+00],
#        [9.710e+00, 7.470e+00, 4.130e+00],
#        [8.920e+00, 8.030e+00, 3.600e+00],
#        [1.500e+01, 4.890e+00, 2.400e-01],
#        [9.010e+00, 8.490e+00, 2.530e+00],
#        [7.020e+00, 9.090e+00, 9.800e-01],
#        [4.740e+00, 9.200e+00, 4.160e+00],
#        [9.660e+00, 5.140e+00, 6.000e-02],
#        [8.410e+00, 5.490e+00, 4.700e-01],
#        [3.430e+00, 5.350e+00, 5.320e+00],
#        [6.850e+00, 5.090e+00, 1.870e+00],
#        [9.040e+00, 4.240e+00, 1.300e-01],
#        [9.700e+00, 3.680e+00, 1.100e-01],
#        [4.990e+00, 5.730e+00, 6.500e-01],
#        [8.250e+00, 4.240e+00, 7.000e-02],
#        [8.520e+00, 3.590e+00, 8.000e-02],
#        [5.540e+00, 5.730e+00, 4.900e-01],
#        [6.990e+00, 4.510e+00, 3.000e-01],
#        [6.620e+00, 2.550e+00, 2.660e+00],
#        [5.030e+00, 4.020e+00, 2.690e+00],
#        [5.990e+00, 4.370e+00, 4.800e-01],
#        [3.960e+00, 6.310e+00, 3.800e-01],
#        [2.500e+00, 3.450e+00, 5.330e+00],
#        [7.970e+00, 2.810e+00, 1.300e-01],
#        [6.060e+00, 3.350e+00, 1.200e+00],
#        [6.760e+00, 3.070e+00, 1.400e-01],
#        [4.020e+00, 3.870e+00, 2.540e+00],
#        [4.890e+00, 3.000e+00, 2.140e+00],
#        [2.960e+00, 4.820e+00, 8.100e-01],
#        [4.990e+00, 3.640e+00, 3.800e-01],
#        [4.760e+00, 3.690e+00, 4.400e-01],
#        [6.730e+00, 2.560e+00, 4.000e-02],
#        [5.950e+00, 3.110e+00, 0.000e+00],
#        [3.660e+00, 3.140e+00, 2.470e+00],
#        [7.040e+00, 1.950e+00, 8.000e-02],
#        [3.010e+00, 2.470e+00, 3.280e+00],
#        [6.650e+00, 2.280e+00, 4.000e-02],
#        [3.880e+00, 3.420e+00, 1.690e+00],
#        [5.800e+00, 2.850e+00, 1.000e-02],
#        [4.100e+00, 3.630e+00, 3.800e-01],
#        [5.930e+00, 2.360e+00, 1.300e-01],
#        [2.030e+00, 2.360e+00, 4.390e+00],
#        [4.400e+00, 1.850e+00, 1.980e+00],
#        [5.050e+00, 2.790e+00, 1.000e-01],
#        [1.120e+00, 6.120e+00, 6.000e-02],
#        [6.820e+00, 1.530e+00, 5.000e-02],
#        [1.750e+00, 3.470e+00, 2.490e+00],
#        [3.740e+00, 2.240e+00, 1.580e+00],
#        [1.060e+00, 5.010e+00, 1.300e-01],
#        [2.910e+00, 2.070e+00, 2.730e+00],
#        [2.280e+00, 1.720e+00, 3.630e+00],
#        [2.760e+00, 1.720e+00, 2.690e+00],
#        [2.900e+00, 2.810e+00, 2.400e-01],
#        [2.810e+00, 3.480e+00, 1.400e-01],
#        [3.560e+00, 2.350e+00, 9.800e-01],
#        [4.810e+00, 1.880e+00, 0.000e+00],
#        [4.460e+00, 2.110e+00, 6.000e-02],
#        [3.270e+00, 2.830e+00, 8.000e-02],
#        [3.480e+00, 2.990e+00, 0.000e+00],
#        [2.850e+00, 2.890e+00, 3.500e-01],
#        [2.530e+00, 3.270e+00, 2.400e-01],
#        [3.270e+00, 2.220e+00, 1.400e+00],
#        [3.740e+00, 2.140e+00, 6.000e-01],
#        [3.680e+00, 1.750e+00, 1.420e+00],
#        [3.150e+00, 2.150e+00, 1.280e+00],
#        [4.410e+00, 1.040e+00, 1.390e+00],
#        [2.710e+00, 3.020e+00, 8.000e-02],
#        [2.930e+00, 2.750e+00, 1.700e-01],
#        [4.050e+00, 2.160e+00, 0.000e+00],
#        [4.150e+00, 1.900e+00, 6.000e-02],
#        [2.770e+00, 2.750e+00, 1.900e-01],
#        [3.110e+00, 2.260e+00, 2.800e-01],
#        [3.270e+00, 2.200e+00, 2.100e-01],
#        [1.660e+00, 2.750e+00, 1.600e+00],
#        [2.790e+00, 2.530e+00, 1.700e-01],
#        [2.640e+00, 2.520e+00, 1.600e-01],
#        [3.170e+00, 1.790e+00, 1.030e+00],
#        [4.980e+00, 1.300e+00, 8.000e-02],
#        [2.550e+00, 2.600e+00, 2.500e-01],
#        [2.570e+00, 1.580e+00, 2.060e+00],
#        [3.640e+00, 1.200e+00, 1.490e+00],
#        [4.340e+00, 1.340e+00, 6.000e-02],
#        [3.700e+00, 1.950e+00, 9.000e-02],
#        [4.010e+00, 1.260e+00, 8.700e-01],
#        [3.110e+00, 2.800e+00, 2.000e-02],
#        [4.050e+00, 1.590e+00, 7.000e-02],
#        [3.920e+00, 1.730e+00, 3.000e-02],
#        [3.540e+00, 1.880e+00, 7.000e-02],
#        [2.450e+00, 2.010e+00, 8.700e-01],
#        [3.180e+00, 1.830e+00, 7.800e-01],
#        [2.630e+00, 1.710e+00, 8.300e-01],
#        [2.410e+00, 2.180e+00, 2.800e-01],
#        [2.800e+00, 1.980e+00, 1.700e-01],
#        [1.880e+00, 1.470e+00, 2.020e+00],
#        [2.260e+00, 1.890e+00, 1.360e+00],
#        [2.490e+00, 2.070e+00, 1.600e-01],
#        [3.570e+00, 1.550e+00, 0.000e+00],
#        [3.070e+00, 1.910e+00, 7.000e-02],
#        [2.540e+00, 1.930e+00, 2.100e-01],
#        [3.280e+00, 1.640e+00, 7.000e-02],
#        [2.990e+00, 1.900e+00, 1.000e-01],
#        [3.140e+00, 1.240e+00, 9.100e-01],
#        [2.710e+00, 1.850e+00, 1.100e-01],
#        [2.810e+00, 2.190e+00, 0.000e+00],
#        [2.620e+00, 1.640e+00, 9.900e-01],
#        [2.070e+00, 2.290e+00, 2.400e-01],
#        [2.730e+00, 1.830e+00, 0.000e+00],
#        [1.850e+00, 2.500e+00, 1.900e-01],
#        [1.740e+00, 1.210e+00, 1.870e+00],
#        [3.130e+00, 1.690e+00, 3.000e-02],
#        [1.920e+00, 1.080e+00, 2.110e+00],
#        [3.220e+00, 1.550e+00, 1.000e-02],
#        [3.110e+00, 1.550e+00, 8.000e-02],
#        [2.300e+00, 1.340e+00, 1.270e+00],
#        [1.210e+00, 2.430e+00, 1.030e+00],
#        [1.090e+00, 3.470e+00, 3.000e-02],
#        [2.440e+00, 2.160e+00, 0.000e+00],
#        [1.980e+00, 2.230e+00, 1.300e-01],
#        [3.590e+00, 1.080e+00, 5.000e-02],
#        [1.960e+00, 1.410e+00, 1.080e+00],
#        [1.850e+00, 1.800e+00, 9.500e-01],
#        [2.050e+00, 1.160e+00, 1.110e+00],
#        [1.700e+00, 1.990e+00, 1.600e-01],
#        [3.420e+00, 1.380e+00, 2.000e-02],
#        [3.050e+00, 1.170e+00, 2.900e-01],
#        [2.310e+00, 1.720e+00, 1.200e-01],
#        [2.570e+00, 1.680e+00, 0.000e+00],
#        [1.910e+00, 2.000e+00, 9.000e-02],
#        [2.740e+00, 1.330e+00, 1.200e-01],
#        [2.570e+00, 1.570e+00, 4.400e-01],
#        [2.830e+00, 1.480e+00, 0.000e+00],
#        [2.360e+00, 2.100e+00, 2.000e-02],
#        [2.990e+00, 1.270e+00, 4.000e-02],
#        [3.050e+00, 1.410e+00, 2.000e-02],
#        [1.940e+00, 1.950e+00, 8.000e-02],
#        [2.290e+00, 1.970e+00, 1.300e-01],
#        [1.820e+00, 1.120e+00, 1.320e+00],
#        [2.070e+00, 1.710e+00, 8.000e-02],
#        [3.040e+00, 1.110e+00, 0.000e+00],
#        [1.800e+00, 1.390e+00, 1.110e+00],
#        [2.080e+00, 1.970e+00, 6.000e-02],
#        [2.780e+00, 1.270e+00, 3.000e-02],
#        [2.710e+00, 1.510e+00, 3.000e-02],
#        [1.610e+00, 2.000e+00, 1.500e-01],
#        [2.710e+00, 1.290e+00, 2.000e-02],
#        [1.540e+00, 1.180e+00, 1.460e+00],
#        [2.520e+00, 1.110e+00, 4.600e-01],
#        [2.660e+00, 1.290e+00, 1.000e-02],
#        [2.820e+00, 1.030e+00, 1.300e-01],
#        [2.030e+00, 1.790e+00, 8.000e-02],
#        [2.640e+00, 1.330e+00, 1.000e-02],
#        [1.740e+00, 1.720e+00, 1.400e-01],
#        [2.110e+00, 1.160e+00, 7.300e-01],
#        [2.510e+00, 1.240e+00, 1.100e-01],
#        [3.000e+00, 1.110e+00, 5.000e-02],
#        [2.240e+00, 1.310e+00, 7.000e-02],
#        [1.410e+00, 2.010e+00, 1.000e-01],
#        [2.510e+00, 1.320e+00, 1.000e-02],
#        [2.450e+00, 1.010e+00, 0.000e+00],
#        [1.280e+00, 1.820e+00, 5.700e-01],
#        [2.250e+00, 1.470e+00, 4.000e-02],
#        [2.030e+00, 1.040e+00, 5.800e-01],
#        [2.570e+00, 1.520e+00, 0.000e+00],
#        [1.100e+00, 2.150e+00, 2.100e-01],
#        [2.660e+00, 1.030e+00, 4.000e-02],
#        [2.350e+00, 1.270e+00, 3.000e-02],
#        [2.120e+00, 1.470e+00, 5.000e-02],
#        [1.400e+00, 1.900e+00, 1.100e-01],
#        [1.680e+00, 1.510e+00, 5.100e-01],
#        [1.130e+00, 2.180e+00, 1.000e-01],
#        [1.020e+00, 2.130e+00, 2.300e-01],
#        [1.190e+00, 2.070e+00, 8.000e-02],
#        [1.530e+00, 1.690e+00, 1.000e-01],
#        [2.030e+00, 1.160e+00, 3.700e-01],
#        [2.150e+00, 1.130e+00, 7.000e-02],
#        [2.090e+00, 1.350e+00, 6.000e-02],
#        [2.290e+00, 1.170e+00, 1.000e-02],
#        [1.160e+00, 2.120e+00, 0.000e+00],
#        [1.530e+00, 1.600e+00, 6.000e-02],
#        [2.130e+00, 1.120e+00, 1.000e-01],
#        [1.780e+00, 1.430e+00, 5.000e-02],
#        [1.350e+00, 1.700e+00, 1.500e-01],
#        [1.050e+00, 1.910e+00, 4.100e-01],
#        [2.400e+00, 1.010e+00, 0.000e+00],
#        [2.030e+00, 1.560e+00, 0.000e+00],
#        [1.370e+00, 2.000e+00, 1.400e-01],
#        [1.930e+00, 1.580e+00, 0.000e+00],
#        [1.330e+00, 1.680e+00, 1.300e-01],
#        [2.130e+00, 1.180e+00, 1.000e-02],
#        [1.580e+00, 1.590e+00, 8.000e-02],
#        [1.650e+00, 1.210e+00, 0.000e+00],
#        [2.080e+00, 1.090e+00, 1.500e-01],
#        [1.930e+00, 1.220e+00, 3.000e-02],
#        [2.020e+00, 1.170e+00, 0.000e+00],
#        [1.350e+00, 1.550e+00, 1.700e-01],
#        [2.180e+00, 1.020e+00, 3.000e-02],
#        [1.600e+00, 1.490e+00, 1.000e-01],
#        [1.560e+00, 1.400e+00, 7.000e-02],
#        [1.230e+00, 1.770e+00, 5.000e-02],
#        [1.900e+00, 1.130e+00, 1.000e-01],
#        [1.300e+00, 1.420e+00, 2.700e-01],
#        [2.150e+00, 1.010e+00, 2.000e-02],
#        [2.100e+00, 1.010e+00, 4.000e-02],
#        [2.100e+00, 1.010e+00, 1.000e-02],
#        [1.550e+00, 1.270e+00, 3.300e-01],
#        [1.130e+00, 2.070e+00, 0.000e+00],
#        [1.090e+00, 1.360e+00, 4.900e-01],
#        [1.750e+00, 1.200e+00, 2.000e-02],
#        [1.830e+00, 1.050e+00, 6.000e-02],
#        [1.560e+00, 1.470e+00, 1.900e-01],
#        [2.040e+00, 1.020e+00, 0.000e+00],
#        [1.450e+00, 1.290e+00, 1.200e-01],
#        [1.470e+00, 1.390e+00, 3.000e-02],
#        [1.990e+00, 1.050e+00, 5.000e-02],
#        [1.900e+00, 1.110e+00, 1.000e-02],
#        [1.500e+00, 1.280e+00, 5.000e-02],
#        [1.890e+00, 1.050e+00, 2.000e-02],
#        [1.350e+00, 1.110e+00, 4.600e-01],
#        [1.780e+00, 1.120e+00, 9.000e-02],
#        [1.270e+00, 1.290e+00, 1.200e-01],
#        [1.700e+00, 1.250e+00, 2.000e-02],
#        [1.060e+00, 1.090e+00, 7.600e-01],
#        [1.210e+00, 1.560e+00, 6.000e-02],
#        [1.520e+00, 1.030e+00, 1.000e-01],
#        [1.400e+00, 1.010e+00, 4.600e-01],
#        [1.720e+00, 1.210e+00, 0.000e+00],
#        [1.750e+00, 1.010e+00, 0.000e+00],
#        [1.290e+00, 1.210e+00, 6.000e-02],
#        [1.850e+00, 1.040e+00, 0.000e+00],
#        [1.400e+00, 1.060e+00, 8.000e-02],
#        [1.380e+00, 1.320e+00, 2.000e-02],
#        [1.670e+00, 1.180e+00, 0.000e+00],
#        [1.580e+00, 1.010e+00, 0.000e+00],
#        [1.010e+00, 1.430e+00, 5.000e-02],
#        [1.040e+00, 1.370e+00, 6.000e-02],
#        [1.360e+00, 1.150e+00, 4.000e-02],
#        [1.330e+00, 1.100e+00, 8.000e-02],
#        [1.540e+00, 1.140e+00, 0.000e+00],
#        [1.410e+00, 1.120e+00, 5.000e-02],
#        [1.510e+00, 1.120e+00, 1.000e-02],
#        [1.070e+00, 1.310e+00, 6.000e-02],
#        [1.280e+00, 1.040e+00, 7.000e-02],
#        [1.050e+00, 1.230e+00, 3.000e-02],
#        [1.350e+00, 1.130e+00, 0.000e+00],
#        [1.410e+00, 1.120e+00, 0.000e+00],
#        [1.250e+00, 1.140e+00, 7.000e-02],
#        [1.210e+00, 1.190e+00, 4.000e-02],
#        [1.230e+00, 1.110e+00, 0.000e+00],
#        [1.440e+00, 1.090e+00, 0.000e+00],
#        [1.150e+00, 1.110e+00, 0.000e+00],
#        [1.050e+00, 1.050e+00, 2.400e-01],
#        [1.130e+00, 1.120e+00, 6.000e-02],
#        [1.070e+00, 1.190e+00, 0.000e+00]])

# %%
# Wii 1 0
# PS2 0 1
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
onehotencorder = ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), [0, 2, 3, 8])], remainder='passthrough') 
previsores = onehotencorder.fit_transform(previsores).toarray()

# %%
previsores.shape
# Out:
# (258, 61)

# %% [markdown]
# ## Etapa 3: Construção do modelo

# %%
# 61 -> 32 -> 32 -> 3
class regressor_torch(nn.Module):
    def __init__(self):
        super().__init__()
        self.dense0 = nn.Linear(61, 32)
        self.dense1 = nn.Linear(32, 32)
        self.activation = nn.Sigmoid()
        self.output = nn.Linear(32, 3)
        
    def forward(self, X):
        X = self.dense0(X)
        X = self.activation(X)
        X = self.dense1(X)
        X = self.activation(X)
        X = self.output(X)
        return X

# %%
regressor = regressor_torch()

# %%
criterion = nn.MSELoss()
optimizer = optim.Adam(regressor.parameters())

# %%
type(previsores)
# Out:
# torch.Tensor

# %%
previsores = torch.tensor(previsores, dtype=torch.float)
vendas = torch.tensor(vendas, dtype=torch.float)
# Out:
# <ipython-input-52-cd210568ec01>:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   previsores = torch.tensor(previsores, dtype=torch.float)
# <ipython-input-52-cd210568ec01>:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   vendas = torch.tensor(vendas, dtype=torch.float)

# %%
type(previsores)
# Out:
# torch.Tensor

# %%
dataset = torch.utils.data.TensorDataset(previsores, vendas)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = 10, shuffle = True)

# %% [markdown]
# ## Etapa 4: Treinamento do modelo

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
regressor.to(device)
# Out:
# regressor_torch(
#   (dense0): Linear(in_features=61, out_features=32, bias=True)
#   (dense1): Linear(in_features=32, out_features=32, bias=True)
#   (activation): Sigmoid()
#   (output): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
for epoch in range(2000):
    
    running_loss = 0.
    running_mse_0 = 0.
    running_mse_1 = 0.
    running_mse_2 = 0.
    
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
       
        optimizer.zero_grad()

        outputs = regressor(inputs)

        mse_0 = F.mse_loss(outputs[:,0], labels[:,0]).item()
        mse_1 = F.mse_loss(outputs[:,1], labels[:,1]).item()
        mse_2 = F.mse_loss(outputs[:,2], labels[:,2]).item()
        
        running_mse_0 += mse_0 * len(inputs)
        running_mse_1 += mse_1 * len(inputs)
        running_mse_2 += mse_2 * len(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        
        optimizer.step()

        loss = loss.item()
        running_loss += loss * len(inputs)

        print('\rÉpoca {:4d} - Loop {:3d} de {:3d}: erro_0 {:6.4f} | erro_1 {:6.4f} | erro_2 {:6.4f} - custo {:6.4f}'.format(epoch + 1,
                      i + 1,
                      len(train_loader),
                      mse_0,
                      mse_1,
                      mse_2,
                      loss), end = '\r')

    print('ÉPOCA {:4d} finalizada: erro_0 {:6.4f} | erro_1 {:6.4f} | erro_2 {:6.4f} - custo {:6.4f}         '.format(epoch + 1, 
         running_mse_0/len(dataset), 
         running_mse_1/len(dataset), 
         running_mse_2/len(dataset), 
         running_loss/len(dataset)))
# Out:
# ÉPOCA    1 finalizada: erro_0 21.8178 | erro_1 13.7230 | erro_2 1.3285 - custo 12.2898
# ÉPOCA    2 finalizada: erro_0 18.2655 | erro_1 10.4217 | erro_2 1.1840 - custo 9.9571
# ÉPOCA    3 finalizada: erro_0 15.5166 | erro_1 8.2907 | erro_2 1.1737 - custo 8.3270
# ÉPOCA    4 finalizada: erro_0 13.6868 | erro_1 6.9916 | erro_2 1.1744 - custo 7.2843
# ÉPOCA    5 finalizada: erro_0 12.7259 | erro_1 6.3374 | erro_2 1.1725 - custo 6.7453
# ÉPOCA    6 finalizada: erro_0 12.2527 | erro_1 6.0233 | erro_2 1.1762 - custo 6.4841
# ÉPOCA    7 finalizada: erro_0 12.0585 | erro_1 5.9109 | erro_2 1.1721 - custo 6.3805
# ÉPOCA    8 finalizada: erro_0 11.9757 | erro_1 5.8674 | erro_2 1.1703 - custo 6.3378
# ÉPOCA    9 finalizada: erro_0 11.9577 | erro_1 5.8557 | erro_2 1.1777 - custo 6.3304
# ÉPOCA   10 finalizada: erro_0 11.9361 | erro_1 5.8517 | erro_2 1.1753 - custo 6.3211
# ÉPOCA   11 finalizada: erro_0 11.9387 | erro_1 5.8532 | erro_2 1.1740 - custo 6.3220
# ÉPOCA   12 finalizada: erro_0 11.9571 | erro_1 5.8533 | erro_2 1.1649 - custo 6.3251
# ÉPOCA   13 finalizada: erro_0 11.9337 | erro_1 5.8528 | erro_2 1.1705 - custo 6.3190
# ÉPOCA   14 finalizada: erro_0 11.9247 | erro_1 5.8468 | erro_2 1.1642 - custo 6.3119
# ÉPOCA   15 finalizada: erro_0 11.9324 | erro_1 5.8592 | erro_2 1.1661 - custo 6.3192
# ÉPOCA   16 finalizada: erro_0 11.9279 | erro_1 5.8482 | erro_2 1.1657 - custo 6.3139
# ÉPOCA   17 finalizada: erro_0 11.9080 | erro_1 5.8431 | erro_2 1.1680 - custo 6.3064
# ÉPOCA   18 finalizada: erro_0 11.9172 | erro_1 5.8453 | erro_2 1.1666 - custo 6.3097
# ÉPOCA   19 finalizada: erro_0 11.9032 | erro_1 5.8452 | erro_2 1.1667 - custo 6.3050
# ÉPOCA   20 finalizada: erro_0 11.9076 | erro_1 5.8403 | erro_2 1.1616 - custo 6.3032
# ÉPOCA   21 finalizada: erro_0 11.9186 | erro_1 5.8448 | erro_2 1.1665 - custo 6.3100
# ÉPOCA   22 finalizada: erro_0 11.9097 | erro_1 5.8366 | erro_2 1.1614 - custo 6.3026
# ÉPOCA   23 finalizada: erro_0 11.9093 | erro_1 5.8420 | erro_2 1.1626 - custo 6.3046
# ÉPOCA   24 finalizada: erro_0 11.8998 | erro_1 5.8386 | erro_2 1.1630 - custo 6.3005
# ÉPOCA   25 finalizada: erro_0 11.8902 | erro_1 5.8340 | erro_2 1.1628 - custo 6.2957
# ÉPOCA   26 finalizada: erro_0 11.8832 | erro_1 5.8270 | erro_2 1.1602 - custo 6.2901
# ÉPOCA   27 finalizada: erro_0 11.9106 | erro_1 5.8544 | erro_2 1.1639 - custo 6.3096
# ÉPOCA   28 finalizada: erro_0 11.9102 | erro_1 5.8465 | erro_2 1.1591 - custo 6.3053
# ÉPOCA   29 finalizada: erro_0 11.8687 | erro_1 5.8289 | erro_2 1.1601 - custo 6.2859
# ÉPOCA   30 finalizada: erro_0 11.8763 | erro_1 5.8362 | erro_2 1.1634 - custo 6.2920
# ÉPOCA   31 finalizada: erro_0 11.8914 | erro_1 5.8391 | erro_2 1.1583 - custo 6.2963
# ÉPOCA   32 finalizada: erro_0 11.8955 | erro_1 5.8435 | erro_2 1.1592 - custo 6.2994
# ÉPOCA   33 finalizada: erro_0 11.8872 | erro_1 5.8321 | erro_2 1.1560 - custo 6.2917
# ÉPOCA   34 finalizada: erro_0 11.8894 | erro_1 5.8401 | erro_2 1.1567 - custo 6.2954
# ÉPOCA   35 finalizada: erro_0 11.8682 | erro_1 5.8291 | erro_2 1.1571 - custo 6.2848
# ÉPOCA   36 finalizada: erro_0 11.8937 | erro_1 5.8416 | erro_2 1.1550 - custo 6.2967
# ÉPOCA   37 finalizada: erro_0 11.8823 | erro_1 5.8265 | erro_2 1.1563 - custo 6.2884
# ÉPOCA   38 finalizada: erro_0 11.8901 | erro_1 5.8487 | erro_2 1.1607 - custo 6.2998
# ÉPOCA   39 finalizada: erro_0 11.8610 | erro_1 5.8251 | erro_2 1.1580 - custo 6.2814
# ÉPOCA   40 finalizada: erro_0 11.8810 | erro_1 5.8422 | erro_2 1.1532 - custo 6.2922
# ÉPOCA   41 finalizada: erro_0 11.8584 | erro_1 5.8243 | erro_2 1.1571 - custo 6.2799
# ÉPOCA   42 finalizada: erro_0 11.8293 | erro_1 5.8151 | erro_2 1.1554 - custo 6.2666
# ÉPOCA   43 finalizada: erro_0 11.8664 | erro_1 5.8297 | erro_2 1.1534 - custo 6.2832
# ÉPOCA   44 finalizada: erro_0 11.8083 | erro_1 5.8111 | erro_2 1.1555 - custo 6.2583
# ÉPOCA   45 finalizada: erro_0 11.8632 | erro_1 5.8202 | erro_2 1.1481 - custo 6.2771
# ÉPOCA   46 finalizada: erro_0 11.8613 | erro_1 5.8182 | erro_2 1.1500 - custo 6.2765
# ÉPOCA   47 finalizada: erro_0 11.8017 | erro_1 5.8091 | erro_2 1.1598 - custo 6.2569
# ÉPOCA   48 finalizada: erro_0 11.8440 | erro_1 5.8297 | erro_2 1.1503 - custo 6.2747
# ÉPOCA   49 finalizada: erro_0 11.7909 | erro_1 5.8082 | erro_2 1.1551 - custo 6.2514
# ÉPOCA   50 finalizada: erro_0 11.8447 | erro_1 5.8210 | erro_2 1.1584 - custo 6.2747
# ÉPOCA   51 finalizada: erro_0 11.8659 | erro_1 5.8308 | erro_2 1.1531 - custo 6.2833
# ÉPOCA   52 finalizada: erro_0 11.7870 | erro_1 5.8012 | erro_2 1.1487 - custo 6.2456
# ÉPOCA   53 finalizada: erro_0 11.7672 | erro_1 5.7999 | erro_2 1.1485 - custo 6.2385
# ÉPOCA   54 finalizada: erro_0 11.7963 | erro_1 5.8130 | erro_2 1.1553 - custo 6.2548
# ÉPOCA   55 finalizada: erro_0 11.7761 | erro_1 5.7947 | erro_2 1.1422 - custo 6.2377
# ÉPOCA   56 finalizada: erro_0 11.7530 | erro_1 5.7930 | erro_2 1.1430 - custo 6.2296
# ÉPOCA   57 finalizada: erro_0 11.7785 | erro_1 5.7921 | erro_2 1.1414 - custo 6.2374
# ÉPOCA   58 finalizada: erro_0 11.7533 | erro_1 5.7814 | erro_2 1.1364 - custo 6.2237
# ÉPOCA   59 finalizada: erro_0 11.7790 | erro_1 5.7979 | erro_2 1.1387 - custo 6.2386
# ÉPOCA   60 finalizada: erro_0 11.7928 | erro_1 5.8066 | erro_2 1.1433 - custo 6.2476
# ÉPOCA   61 finalizada: erro_0 11.7384 | erro_1 5.7793 | erro_2 1.1374 - custo 6.2184
# ÉPOCA   62 finalizada: erro_0 11.8130 | erro_1 5.8167 | erro_2 1.1313 - custo 6.2537
# ÉPOCA   63 finalizada: erro_0 11.7367 | erro_1 5.7824 | erro_2 1.1246 - custo 6.2146
# ÉPOCA   64 finalizada: erro_0 11.7780 | erro_1 5.7989 | erro_2 1.1248 - custo 6.2339
# ÉPOCA   65 finalizada: erro_0 11.7335 | erro_1 5.7846 | erro_2 1.1245 - custo 6.2142
# ÉPOCA   66 finalizada: erro_0 11.7373 | erro_1 5.7867 | erro_2 1.1313 - custo 6.2184
# ÉPOCA   67 finalizada: erro_0 11.7766 | erro_1 5.8077 | erro_2 1.1315 - custo 6.2386
# ÉPOCA   68 finalizada: erro_0 11.7383 | erro_1 5.7799 | erro_2 1.1239 - custo 6.2140
# ÉPOCA   69 finalizada: erro_0 11.7280 | erro_1 5.7809 | erro_2 1.1277 - custo 6.2122
# ÉPOCA   70 finalizada: erro_0 11.6987 | erro_1 5.7683 | erro_2 1.1258 - custo 6.1976
# ÉPOCA   71 finalizada: erro_0 11.7433 | erro_1 5.7696 | erro_2 1.1228 - custo 6.2119
# ÉPOCA   72 finalizada: erro_0 11.6895 | erro_1 5.7631 | erro_2 1.1193 - custo 6.1906
# ÉPOCA   73 finalizada: erro_0 11.7457 | erro_1 5.7778 | erro_2 1.1151 - custo 6.2129
# ÉPOCA   74 finalizada: erro_0 11.6949 | erro_1 5.7674 | erro_2 1.1155 - custo 6.1926
# ÉPOCA   75 finalizada: erro_0 11.7040 | erro_1 5.7538 | erro_2 1.1210 - custo 6.1930
# ÉPOCA   76 finalizada: erro_0 11.7926 | erro_1 5.7979 | erro_2 1.1432 - custo 6.2446
# ÉPOCA   77 finalizada: erro_0 11.8043 | erro_1 5.8015 | erro_2 1.1371 - custo 6.2476
# ÉPOCA   78 finalizada: erro_0 11.7709 | erro_1 5.7767 | erro_2 1.1304 - custo 6.2260
# ÉPOCA   79 finalizada: erro_0 11.7757 | erro_1 5.7937 | erro_2 1.1370 - custo 6.2355
# ÉPOCA   80 finalizada: erro_0 11.7763 | erro_1 5.7796 | erro_2 1.1174 - custo 6.2244
# ÉPOCA   81 finalizada: erro_0 11.7761 | erro_1 5.7835 | erro_2 1.1162 - custo 6.2253
# ÉPOCA   82 finalizada: erro_0 11.7681 | erro_1 5.7746 | erro_2 1.1166 - custo 6.2198
# ÉPOCA   83 finalizada: erro_0 11.7553 | erro_1 5.7797 | erro_2 1.1284 - custo 6.2211
# ÉPOCA   84 finalizada: erro_0 11.8137 | erro_1 5.7842 | erro_2 1.1131 - custo 6.2370
# ÉPOCA   85 finalizada: erro_0 11.7755 | erro_1 5.7746 | erro_2 1.1218 - custo 6.2239
# ÉPOCA   86 finalizada: erro_0 11.7604 | erro_1 5.7791 | erro_2 1.1155 - custo 6.2183
# ÉPOCA   87 finalizada: erro_0 11.7717 | erro_1 5.7712 | erro_2 1.1147 - custo 6.2192
# ÉPOCA   88 finalizada: erro_0 11.8184 | erro_1 5.7937 | erro_2 1.1170 - custo 6.2430
# ÉPOCA   89 finalizada: erro_0 11.7452 | erro_1 5.7571 | erro_2 1.1032 - custo 6.2019
# ÉPOCA   90 finalizada: erro_0 11.7302 | erro_1 5.7568 | erro_2 1.1096 - custo 6.1989
# ÉPOCA   91 finalizada: erro_0 11.7363 | erro_1 5.7593 | erro_2 1.1108 - custo 6.2021
# ÉPOCA   92 finalizada: erro_0 11.7456 | erro_1 5.7596 | erro_2 1.1175 - custo 6.2076
# ÉPOCA   93 finalizada: erro_0 11.7651 | erro_1 5.7724 | erro_2 1.1179 - custo 6.2185
# ÉPOCA   94 finalizada: erro_0 11.7347 | erro_1 5.7597 | erro_2 1.1031 - custo 6.1992
# ÉPOCA   95 finalizada: erro_0 11.7100 | erro_1 5.7510 | erro_2 1.1082 - custo 6.1897
# ÉPOCA   96 finalizada: erro_0 11.7558 | erro_1 5.7593 | erro_2 1.1188 - custo 6.2113
# ÉPOCA   97 finalizada: erro_0 11.7310 | erro_1 5.7585 | erro_2 1.1173 - custo 6.2023
# ÉPOCA   98 finalizada: erro_0 11.8411 | erro_1 5.8186 | erro_2 1.1255 - custo 6.2617
# ÉPOCA   99 finalizada: erro_0 11.8452 | erro_1 5.7987 | erro_2 1.1094 - custo 6.2511
# ÉPOCA  100 finalizada: erro_0 11.7853 | erro_1 5.7566 | erro_2 1.1039 - custo 6.2153
# ÉPOCA  101 finalizada: erro_0 11.7080 | erro_1 5.7413 | erro_2 1.0940 - custo 6.1811
# ÉPOCA  102 finalizada: erro_0 11.7333 | erro_1 5.7702 | erro_2 1.1081 - custo 6.2038
# ÉPOCA  103 finalizada: erro_0 11.7045 | erro_1 5.7390 | erro_2 1.1111 - custo 6.1849
# ÉPOCA  104 finalizada: erro_0 11.7092 | erro_1 5.7543 | erro_2 1.1063 - custo 6.1899
# ÉPOCA  105 finalizada: erro_0 11.7025 | erro_1 5.7387 | erro_2 1.1067 - custo 6.1826
# ÉPOCA  106 finalizada: erro_0 11.7682 | erro_1 5.7665 | erro_2 1.1118 - custo 6.2155
# ÉPOCA  107 finalizada: erro_0 11.6731 | erro_1 5.7218 | erro_2 1.1030 - custo 6.1660
# ÉPOCA  108 finalizada: erro_0 11.7119 | erro_1 5.7377 | erro_2 1.1045 - custo 6.1847
# ÉPOCA  109 finalizada: erro_0 11.6679 | erro_1 5.7161 | erro_2 1.1017 - custo 6.1619
# ÉPOCA  110 finalizada: erro_0 11.7010 | erro_1 5.7239 | erro_2 1.1000 - custo 6.1750
# ÉPOCA  111 finalizada: erro_0 11.6825 | erro_1 5.7277 | erro_2 1.1082 - custo 6.1728
# ÉPOCA  112 finalizada: erro_0 11.6960 | erro_1 5.7346 | erro_2 1.0943 - custo 6.1750
# ÉPOCA  113 finalizada: erro_0 11.6752 | erro_1 5.7225 | erro_2 1.1152 - custo 6.1709
# ÉPOCA  114 finalizada: erro_0 11.6841 | erro_1 5.7254 | erro_2 1.1019 - custo 6.1705
# ÉPOCA  115 finalizada: erro_0 11.6598 | erro_1 5.7171 | erro_2 1.1046 - custo 6.1605
# ÉPOCA  116 finalizada: erro_0 11.6829 | erro_1 5.7271 | erro_2 1.0934 - custo 6.1678
# ÉPOCA  117 finalizada: erro_0 11.6769 | erro_1 5.7178 | erro_2 1.1020 - custo 6.1656
# ÉPOCA  118 finalizada: erro_0 11.7127 | erro_1 5.7371 | erro_2 1.1037 - custo 6.1845
# ÉPOCA  119 finalizada: erro_0 11.7520 | erro_1 5.7630 | erro_2 1.1093 - custo 6.2081
# ÉPOCA  120 finalizada: erro_0 11.6326 | erro_1 5.7061 | erro_2 1.0906 - custo 6.1431
# ÉPOCA  121 finalizada: erro_0 11.6580 | erro_1 5.7042 | erro_2 1.0858 - custo 6.1493
# ÉPOCA  122 finalizada: erro_0 11.6594 | erro_1 5.7179 | erro_2 1.0981 - custo 6.1585
# ÉPOCA  123 finalizada: erro_0 11.6618 | erro_1 5.7151 | erro_2 1.0968 - custo 6.1579
# ÉPOCA  124 finalizada: erro_0 11.6724 | erro_1 5.7220 | erro_2 1.0851 - custo 6.1598
# ÉPOCA  125 finalizada: erro_0 11.6347 | erro_1 5.7003 | erro_2 1.0784 - custo 6.1378
# ÉPOCA  126 finalizada: erro_0 11.6457 | erro_1 5.7020 | erro_2 1.1022 - custo 6.1499
# ÉPOCA  127 finalizada: erro_0 11.6948 | erro_1 5.7255 | erro_2 1.1148 - custo 6.1784
# ÉPOCA  128 finalizada: erro_0 11.6782 | erro_1 5.7409 | erro_2 1.1087 - custo 6.1759
# ÉPOCA  129 finalizada: erro_0 11.6987 | erro_1 5.7324 | erro_2 1.1143 - custo 6.1818
# ÉPOCA  130 finalizada: erro_0 11.6817 | erro_1 5.7176 | erro_2 1.0659 - custo 6.1551
# ÉPOCA  131 finalizada: erro_0 11.6143 | erro_1 5.6858 | erro_2 1.0857 - custo 6.1286
# ÉPOCA  132 finalizada: erro_0 11.6639 | erro_1 5.7123 | erro_2 1.1151 - custo 6.1638
# ÉPOCA  133 finalizada: erro_0 11.7186 | erro_1 5.7244 | erro_2 1.1046 - custo 6.1825
# ÉPOCA  134 finalizada: erro_0 11.7044 | erro_1 5.7300 | erro_2 1.0948 - custo 6.1764
# ÉPOCA  135 finalizada: erro_0 11.6788 | erro_1 5.7295 | erro_2 1.1034 - custo 6.1706
# ÉPOCA  136 finalizada: erro_0 11.8402 | erro_1 5.7969 | erro_2 1.1211 - custo 6.2527
# ÉPOCA  137 finalizada: erro_0 11.9233 | erro_1 5.8209 | erro_2 1.1321 - custo 6.2921
# ÉPOCA  138 finalizada: erro_0 11.7944 | erro_1 5.7818 | erro_2 1.0864 - custo 6.2209
# ÉPOCA  139 finalizada: erro_0 11.6793 | erro_1 5.7164 | erro_2 1.0760 - custo 6.1572
# ÉPOCA  140 finalizada: erro_0 11.6739 | erro_1 5.7354 | erro_2 1.0958 - custo 6.1683
# ÉPOCA  141 finalizada: erro_0 11.6651 | erro_1 5.7071 | erro_2 1.0903 - custo 6.1542
# ÉPOCA  142 finalizada: erro_0 11.6559 | erro_1 5.7176 | erro_2 1.1127 - custo 6.1621
# ÉPOCA  143 finalizada: erro_0 11.6866 | erro_1 5.7322 | erro_2 1.0916 - custo 6.1701
# ÉPOCA  144 finalizada: erro_0 11.7187 | erro_1 5.7435 | erro_2 1.0668 - custo 6.1763
# ÉPOCA  145 finalizada: erro_0 11.6444 | erro_1 5.7287 | erro_2 1.0704 - custo 6.1478
# ÉPOCA  146 finalizada: erro_0 11.6855 | erro_1 5.7314 | erro_2 1.0766 - custo 6.1645
# ÉPOCA  147 finalizada: erro_0 11.6828 | erro_1 5.7247 | erro_2 1.0762 - custo 6.1612
# ÉPOCA  148 finalizada: erro_0 11.6062 | erro_1 5.6887 | erro_2 1.0696 - custo 6.1215
# ÉPOCA  149 finalizada: erro_0 11.7477 | erro_1 5.7684 | erro_2 1.0506 - custo 6.1889
# ÉPOCA  150 finalizada: erro_0 11.6815 | erro_1 5.7253 | erro_2 1.0670 - custo 6.1579
# ÉPOCA  151 finalizada: erro_0 11.7120 | erro_1 5.7343 | erro_2 1.0702 - custo 6.1722
# ÉPOCA  152 finalizada: erro_0 11.6075 | erro_1 5.6886 | erro_2 1.0535 - custo 6.1165
# ÉPOCA  153 finalizada: erro_0 11.6630 | erro_1 5.7192 | erro_2 1.0662 - custo 6.1495
# ÉPOCA  154 finalizada: erro_0 11.6538 | erro_1 5.7187 | erro_2 1.0587 - custo 6.1437
# ÉPOCA  155 finalizada: erro_0 11.6911 | erro_1 5.7315 | erro_2 1.0541 - custo 6.1589
# ÉPOCA  156 finalizada: erro_0 11.6215 | erro_1 5.6931 | erro_2 1.0426 - custo 6.1191
# ÉPOCA  157 finalizada: erro_0 11.6151 | erro_1 5.6921 | erro_2 1.0705 - custo 6.1259
# ÉPOCA  158 finalizada: erro_0 11.6177 | erro_1 5.7391 | erro_2 1.0689 - custo 6.1419
# ÉPOCA  159 finalizada: erro_0 11.6434 | erro_1 5.7008 | erro_2 1.0680 - custo 6.1374
# ÉPOCA  160 finalizada: erro_0 11.6630 | erro_1 5.7052 | erro_2 1.0593 - custo 6.1425
# ÉPOCA  161 finalizada: erro_0 11.5968 | erro_1 5.6872 | erro_2 1.0704 - custo 6.1181
# ÉPOCA  162 finalizada: erro_0 11.6488 | erro_1 5.6893 | erro_2 1.0518 - custo 6.1300
# ÉPOCA  163 finalizada: erro_0 11.6133 | erro_1 5.6819 | erro_2 1.0506 - custo 6.1153
# ÉPOCA  164 finalizada: erro_0 11.8071 | erro_1 5.7652 | erro_2 1.0736 - custo 6.2153
# ÉPOCA  165 finalizada: erro_0 11.6229 | erro_1 5.7396 | erro_2 1.0669 - custo 6.1431
# ÉPOCA  166 finalizada: erro_0 11.7551 | erro_1 5.7928 | erro_2 1.0706 - custo 6.2062
# ÉPOCA  167 finalizada: erro_0 11.7582 | erro_1 5.7382 | erro_2 1.0551 - custo 6.1838
# ÉPOCA  168 finalizada: erro_0 11.6915 | erro_1 5.7183 | erro_2 1.0480 - custo 6.1526
# ÉPOCA  169 finalizada: erro_0 11.9181 | erro_1 5.7973 | erro_2 1.0901 - custo 6.2685
# ÉPOCA  170 finalizada: erro_0 11.6934 | erro_1 5.7371 | erro_2 1.0848 - custo 6.1718
# ÉPOCA  171 finalizada: erro_0 11.6365 | erro_1 5.6962 | erro_2 1.0470 - custo 6.1266
# ÉPOCA  172 finalizada: erro_0 11.5951 | erro_1 5.6695 | erro_2 1.0384 - custo 6.1010
# ÉPOCA  173 finalizada: erro_0 11.6469 | erro_1 5.7153 | erro_2 1.0558 - custo 6.1393
# ÉPOCA  174 finalizada: erro_0 11.5935 | erro_1 5.6772 | erro_2 1.0421 - custo 6.1043
# ÉPOCA  175 finalizada: erro_0 11.7045 | erro_1 5.7355 | erro_2 1.0438 - custo 6.1613
# ÉPOCA  176 finalizada: erro_0 11.6074 | erro_1 5.7012 | erro_2 1.0616 - custo 6.1234
# ÉPOCA  177 finalizada: erro_0 11.6348 | erro_1 5.7034 | erro_2 1.0714 - custo 6.1365
# ÉPOCA  178 finalizada: erro_0 11.5535 | erro_1 5.6851 | erro_2 1.0503 - custo 6.0963
# ÉPOCA  179 finalizada: erro_0 11.6779 | erro_1 5.7241 | erro_2 1.0579 - custo 6.1533
# ÉPOCA  180 finalizada: erro_0 11.6450 | erro_1 5.7073 | erro_2 1.0533 - custo 6.1352
# ÉPOCA  181 finalizada: erro_0 11.6094 | erro_1 5.7003 | erro_2 1.0603 - custo 6.1233
# ÉPOCA  182 finalizada: erro_0 11.5883 | erro_1 5.7138 | erro_2 1.0630 - custo 6.1217
# ÉPOCA  183 finalizada: erro_0 11.6354 | erro_1 5.6800 | erro_2 1.0614 - custo 6.1256
# ÉPOCA  184 finalizada: erro_0 11.6383 | erro_1 5.6860 | erro_2 1.0625 - custo 6.1290
# ÉPOCA  185 finalizada: erro_0 11.5822 | erro_1 5.6610 | erro_2 1.0535 - custo 6.0989
# ÉPOCA  186 finalizada: erro_0 11.5991 | erro_1 5.6802 | erro_2 1.0844 - custo 6.1212
# ÉPOCA  187 finalizada: erro_0 11.6251 | erro_1 5.6898 | erro_2 1.0982 - custo 6.1377
# ÉPOCA  188 finalizada: erro_0 11.6105 | erro_1 5.6886 | erro_2 1.0930 - custo 6.1307
# ÉPOCA  189 finalizada: erro_0 11.5961 | erro_1 5.6713 | erro_2 1.1028 - custo 6.1234
# ÉPOCA  190 finalizada: erro_0 11.5803 | erro_1 5.6691 | erro_2 1.0901 - custo 6.1132
# ÉPOCA  191 finalizada: erro_0 11.5897 | erro_1 5.6992 | erro_2 1.0839 - custo 6.1242
# ÉPOCA  192 finalizada: erro_0 11.6648 | erro_1 5.7144 | erro_2 1.0668 - custo 6.1487
# ÉPOCA  193 finalizada: erro_0 11.5205 | erro_1 5.6888 | erro_2 1.0728 - custo 6.0940
# ÉPOCA  194 finalizada: erro_0 11.5952 | erro_1 5.7178 | erro_2 1.0893 - custo 6.1341
# ÉPOCA  195 finalizada: erro_0 11.5170 | erro_1 5.6755 | erro_2 1.0676 - custo 6.0867
# ÉPOCA  196 finalizada: erro_0 11.6786 | erro_1 5.7113 | erro_2 1.0735 - custo 6.1545
# ÉPOCA  197 finalizada: erro_0 11.5738 | erro_1 5.6534 | erro_2 1.0709 - custo 6.0994
# ÉPOCA  198 finalizada: erro_0 11.7502 | erro_1 5.7481 | erro_2 1.0671 - custo 6.1884
# ÉPOCA  199 finalizada: erro_0 11.5523 | erro_1 5.6879 | erro_2 1.0660 - custo 6.1021
# ÉPOCA  200 finalizada: erro_0 11.5142 | erro_1 5.6721 | erro_2 1.0654 - custo 6.0839
# ÉPOCA  201 finalizada: erro_0 11.5100 | erro_1 5.6588 | erro_2 1.0626 - custo 6.0771
# ÉPOCA  202 finalizada: erro_0 11.6210 | erro_1 5.7007 | erro_2 1.0597 - custo 6.1271
# ÉPOCA  203 finalizada: erro_0 11.5471 | erro_1 5.6862 | erro_2 1.0691 - custo 6.1008
# ÉPOCA  204 finalizada: erro_0 11.5505 | erro_1 5.6933 | erro_2 1.0755 - custo 6.1064
# ÉPOCA  205 finalizada: erro_0 11.5461 | erro_1 5.6308 | erro_2 1.0715 - custo 6.0828
# ÉPOCA  206 finalizada: erro_0 11.5519 | erro_1 5.6270 | erro_2 1.0720 - custo 6.0836
# ÉPOCA  207 finalizada: erro_0 11.5567 | erro_1 5.6453 | erro_2 1.0874 - custo 6.0965
# ÉPOCA  208 finalizada: erro_0 11.6188 | erro_1 5.6717 | erro_2 1.0955 - custo 6.1287
# ÉPOCA  209 finalizada: erro_0 11.5264 | erro_1 5.6212 | erro_2 1.0742 - custo 6.0739
# ÉPOCA  210 finalizada: erro_0 11.6035 | erro_1 5.6935 | erro_2 1.0867 - custo 6.1279
# ÉPOCA  211 finalizada: erro_0 11.5744 | erro_1 5.6718 | erro_2 1.0524 - custo 6.0996
# ÉPOCA  212 finalizada: erro_0 11.5483 | erro_1 5.6393 | erro_2 1.0417 - custo 6.0764
# ÉPOCA  213 finalizada: erro_0 11.4538 | erro_1 5.6115 | erro_2 1.0439 - custo 6.0364
# ÉPOCA  214 finalizada: erro_0 11.5807 | erro_1 5.6885 | erro_2 1.1008 - custo 6.1233
# ÉPOCA  215 finalizada: erro_0 11.4913 | erro_1 5.6545 | erro_2 1.0945 - custo 6.0801
# ÉPOCA  216 finalizada: erro_0 11.8816 | erro_1 5.8165 | erro_2 1.0931 - custo 6.2637
# ÉPOCA  217 finalizada: erro_0 11.4934 | erro_1 5.6337 | erro_2 1.0615 - custo 6.0629
# ÉPOCA  218 finalizada: erro_0 11.5129 | erro_1 5.6304 | erro_2 1.0785 - custo 6.0739
# ÉPOCA  219 finalizada: erro_0 11.6252 | erro_1 5.6864 | erro_2 1.0520 - custo 6.1212
# ÉPOCA  220 finalizada: erro_0 11.5196 | erro_1 5.6470 | erro_2 1.0603 - custo 6.0757
# ÉPOCA  221 finalizada: erro_0 11.5178 | erro_1 5.6816 | erro_2 1.1142 - custo 6.1045
# ÉPOCA  222 finalizada: erro_0 11.5919 | erro_1 5.6932 | erro_2 1.0831 - custo 6.1227
# ÉPOCA  223 finalizada: erro_0 11.5243 | erro_1 5.6158 | erro_2 1.0723 - custo 6.0708
# ÉPOCA  224 finalizada: erro_0 11.5127 | erro_1 5.6217 | erro_2 1.0669 - custo 6.0671
# ÉPOCA  225 finalizada: erro_0 11.5201 | erro_1 5.6095 | erro_2 1.0692 - custo 6.0663
# ÉPOCA  226 finalizada: erro_0 11.5168 | erro_1 5.6075 | erro_2 1.0785 - custo 6.0676
# ÉPOCA  227 finalizada: erro_0 11.5416 | erro_1 5.6183 | erro_2 1.0655 - custo 6.0752
# ÉPOCA  228 finalizada: erro_0 11.5235 | erro_1 5.6477 | erro_2 1.0855 - custo 6.0856
# ÉPOCA  229 finalizada: erro_0 11.5152 | erro_1 5.6500 | erro_2 1.0964 - custo 6.0872
# ÉPOCA  230 finalizada: erro_0 11.6252 | erro_1 5.7192 | erro_2 1.0778 - custo 6.1407
# ÉPOCA  231 finalizada: erro_0 11.8731 | erro_1 5.8017 | erro_2 1.0951 - custo 6.2567
# ÉPOCA  232 finalizada: erro_0 11.5997 | erro_1 5.7082 | erro_2 1.0832 - custo 6.1304
# ÉPOCA  233 finalizada: erro_0 11.4707 | erro_1 5.5886 | erro_2 1.0410 - custo 6.0334
# ÉPOCA  234 finalizada: erro_0 11.5231 | erro_1 5.6551 | erro_2 1.0555 - custo 6.0779
# ÉPOCA  235 finalizada: erro_0 11.4353 | erro_1 5.5947 | erro_2 1.0301 - custo 6.0200
# ÉPOCA  236 finalizada: erro_0 11.5316 | erro_1 5.6325 | erro_2 1.0451 - custo 6.0697
# ÉPOCA  237 finalizada: erro_0 11.5972 | erro_1 5.6335 | erro_2 1.0417 - custo 6.0908
# ÉPOCA  238 finalizada: erro_0 11.6135 | erro_1 5.6858 | erro_2 1.0631 - custo 6.1208
# ÉPOCA  239 finalizada: erro_0 11.5410 | erro_1 5.6349 | erro_2 1.0666 - custo 6.0808
# ÉPOCA  240 finalizada: erro_0 11.4863 | erro_1 5.6118 | erro_2 1.0696 - custo 6.0559
# ÉPOCA  241 finalizada: erro_0 11.5068 | erro_1 5.6259 | erro_2 1.0697 - custo 6.0675
# ÉPOCA  242 finalizada: erro_0 11.4856 | erro_1 5.6090 | erro_2 1.0675 - custo 6.0540
# ÉPOCA  243 finalizada: erro_0 11.4700 | erro_1 5.5932 | erro_2 1.0697 - custo 6.0443
# ÉPOCA  244 finalizada: erro_0 11.4776 | erro_1 5.6058 | erro_2 1.0757 - custo 6.0530
# ÉPOCA  245 finalizada: erro_0 11.4853 | erro_1 5.5870 | erro_2 1.0583 - custo 6.0435
# ÉPOCA  246 finalizada: erro_0 11.4790 | erro_1 5.5890 | erro_2 1.0656 - custo 6.0445
# ÉPOCA  247 finalizada: erro_0 11.4742 | erro_1 5.5922 | erro_2 1.0554 - custo 6.0406
# ÉPOCA  248 finalizada: erro_0 11.5408 | erro_1 5.6107 | erro_2 1.0585 - custo 6.0700
# ÉPOCA  249 finalizada: erro_0 11.4999 | erro_1 5.6163 | erro_2 1.0587 - custo 6.0583
# ÉPOCA  250 finalizada: erro_0 11.5011 | erro_1 5.6244 | erro_2 1.0606 - custo 6.0620
# ÉPOCA  251 finalizada: erro_0 11.4761 | erro_1 5.5973 | erro_2 1.0551 - custo 6.0428
# ÉPOCA  252 finalizada: erro_0 11.5067 | erro_1 5.6233 | erro_2 1.0677 - custo 6.0659
# ÉPOCA  253 finalizada: erro_0 11.4798 | erro_1 5.6400 | erro_2 1.1045 - custo 6.0748
# ÉPOCA  254 finalizada: erro_0 11.7422 | erro_1 5.8069 | erro_2 1.0624 - custo 6.2039
# ÉPOCA  255 finalizada: erro_0 11.6136 | erro_1 5.6587 | erro_2 1.0506 - custo 6.1076
# ÉPOCA  256 finalizada: erro_0 11.4101 | erro_1 5.5729 | erro_2 1.0388 - custo 6.0073
# ÉPOCA  257 finalizada: erro_0 11.4417 | erro_1 5.5919 | erro_2 1.0374 - custo 6.0237
# ÉPOCA  258 finalizada: erro_0 11.5374 | erro_1 5.6385 | erro_2 1.0571 - custo 6.0776
# ÉPOCA  259 finalizada: erro_0 11.4627 | erro_1 5.5943 | erro_2 1.0463 - custo 6.0344
# ÉPOCA  260 finalizada: erro_0 11.4907 | erro_1 5.6127 | erro_2 1.0557 - custo 6.0530
# ÉPOCA  261 finalizada: erro_0 11.4804 | erro_1 5.6161 | erro_2 1.0624 - custo 6.0529
# ÉPOCA  262 finalizada: erro_0 11.3561 | erro_1 5.5381 | erro_2 1.0407 - custo 5.9783
# ÉPOCA  263 finalizada: erro_0 11.8245 | erro_1 5.8064 | erro_2 1.0831 - custo 6.2380
# ÉPOCA  264 finalizada: erro_0 11.4757 | erro_1 5.6228 | erro_2 1.0442 - custo 6.0476
# ÉPOCA  265 finalizada: erro_0 11.5107 | erro_1 5.6228 | erro_2 1.0402 - custo 6.0579
# ÉPOCA  266 finalizada: erro_0 11.4718 | erro_1 5.5767 | erro_2 1.0326 - custo 6.0271
# ÉPOCA  267 finalizada: erro_0 11.4908 | erro_1 5.6328 | erro_2 1.0410 - custo 6.0549
# ÉPOCA  268 finalizada: erro_0 11.5406 | erro_1 5.6588 | erro_2 1.0593 - custo 6.0862
# ÉPOCA  269 finalizada: erro_0 11.4560 | erro_1 5.6690 | erro_2 1.0914 - custo 6.0721
# ÉPOCA  270 finalizada: erro_0 11.6654 | erro_1 5.8006 | erro_2 1.1453 - custo 6.2038
# ÉPOCA  271 finalizada: erro_0 11.6484 | erro_1 5.7708 | erro_2 1.1141 - custo 6.1778
# ÉPOCA  272 finalizada: erro_0 11.5458 | erro_1 5.7143 | erro_2 1.0987 - custo 6.1196
# ÉPOCA  273 finalizada: erro_0 11.5214 | erro_1 5.7300 | erro_2 1.1165 - custo 6.1227
# ÉPOCA  274 finalizada: erro_0 11.4679 | erro_1 5.6486 | erro_2 1.0619 - custo 6.0595
# ÉPOCA  275 finalizada: erro_0 11.5598 | erro_1 5.7068 | erro_2 1.0570 - custo 6.1079
# ÉPOCA  276 finalizada: erro_0 11.5003 | erro_1 5.6534 | erro_2 1.0679 - custo 6.0739
# ÉPOCA  277 finalizada: erro_0 11.4544 | erro_1 5.6674 | erro_2 1.0725 - custo 6.0648
# ÉPOCA  278 finalizada: erro_0 11.4599 | erro_1 5.6427 | erro_2 1.0597 - custo 6.0541
# ÉPOCA  279 finalizada: erro_0 11.4626 | erro_1 5.6455 | erro_2 1.0533 - custo 6.0538
# ÉPOCA  280 finalizada: erro_0 11.5649 | erro_1 5.7051 | erro_2 1.0936 - custo 6.1212
# ÉPOCA  281 finalizada: erro_0 11.4489 | erro_1 5.7144 | erro_2 1.0899 - custo 6.0844
# ÉPOCA  282 finalizada: erro_0 11.5766 | erro_1 5.7164 | erro_2 1.0811 - custo 6.1247
# ÉPOCA  283 finalizada: erro_0 11.7067 | erro_1 5.8311 | erro_2 1.0997 - custo 6.2125
# ÉPOCA  284 finalizada: erro_0 12.1511 | erro_1 5.9656 | erro_2 1.1452 - custo 6.4206
# ÉPOCA  285 finalizada: erro_0 11.8526 | erro_1 5.8106 | erro_2 1.0857 - custo 6.2497
# ÉPOCA  286 finalizada: erro_0 11.7080 | erro_1 5.7574 | erro_2 1.0632 - custo 6.1762
# ÉPOCA  287 finalizada: erro_0 11.5201 | erro_1 5.6826 | erro_2 1.0473 - custo 6.0833
# ÉPOCA  288 finalizada: erro_0 11.4246 | erro_1 5.6286 | erro_2 1.0407 - custo 6.0313
# ÉPOCA  289 finalizada: erro_0 11.4266 | erro_1 5.6263 | erro_2 1.0427 - custo 6.0319
# ÉPOCA  290 finalizada: erro_0 11.6475 | erro_1 5.7201 | erro_2 1.0619 - custo 6.1432
# ÉPOCA  291 finalizada: erro_0 11.4573 | erro_1 5.6758 | erro_2 1.0956 - custo 6.0762
# ÉPOCA  292 finalizada: erro_0 11.4989 | erro_1 5.6929 | erro_2 1.0836 - custo 6.0918
# ÉPOCA  293 finalizada: erro_0 11.4823 | erro_1 5.6857 | erro_2 1.0727 - custo 6.0802
# ÉPOCA  294 finalizada: erro_0 11.5021 | erro_1 5.7202 | erro_2 1.1082 - custo 6.1102
# ÉPOCA  295 finalizada: erro_0 11.4286 | erro_1 5.6277 | erro_2 1.0525 - custo 6.0363
# ÉPOCA  296 finalizada: erro_0 11.4462 | erro_1 5.6370 | erro_2 1.0486 - custo 6.0439
# ÉPOCA  297 finalizada: erro_0 11.5087 | erro_1 5.6440 | erro_2 1.0465 - custo 6.0664
# ÉPOCA  298 finalizada: erro_0 11.5616 | erro_1 5.6765 | erro_2 1.0408 - custo 6.0930
# ÉPOCA  299 finalizada: erro_0 11.5239 | erro_1 5.6739 | erro_2 1.0417 - custo 6.0798
# ÉPOCA  300 finalizada: erro_0 11.4182 | erro_1 5.6184 | erro_2 1.0319 - custo 6.0228
# ÉPOCA  301 finalizada: erro_0 11.4671 | erro_1 5.6333 | erro_2 1.0406 - custo 6.0470
# ÉPOCA  302 finalizada: erro_0 11.4524 | erro_1 5.6357 | erro_2 1.0342 - custo 6.0408
# ÉPOCA  303 finalizada: erro_0 11.4267 | erro_1 5.6092 | erro_2 1.0320 - custo 6.0226
# ÉPOCA  304 finalizada: erro_0 11.4493 | erro_1 5.6017 | erro_2 1.0270 - custo 6.0260
# ÉPOCA  305 finalizada: erro_0 11.4674 | erro_1 5.6339 | erro_2 1.0227 - custo 6.0413
# ÉPOCA  306 finalizada: erro_0 11.3886 | erro_1 5.6101 | erro_2 1.0367 - custo 6.0118
# ÉPOCA  307 finalizada: erro_0 11.4638 | erro_1 5.6120 | erro_2 1.0317 - custo 6.0358
# ÉPOCA  308 finalizada: erro_0 11.4650 | erro_1 5.5882 | erro_2 1.0280 - custo 6.0271
# ÉPOCA  309 finalizada: erro_0 11.4040 | erro_1 5.5895 | erro_2 1.0473 - custo 6.0136
# ÉPOCA  310 finalizada: erro_0 11.3683 | erro_1 5.6054 | erro_2 1.0402 - custo 6.0046
# ÉPOCA  311 finalizada: erro_0 11.4769 | erro_1 5.6432 | erro_2 1.0438 - custo 6.0546
# ÉPOCA  312 finalizada: erro_0 11.4266 | erro_1 5.6193 | erro_2 1.0343 - custo 6.0267
# ÉPOCA  313 finalizada: erro_0 11.4800 | erro_1 5.6353 | erro_2 1.0463 - custo 6.0539
# ÉPOCA  314 finalizada: erro_0 11.4539 | erro_1 5.6506 | erro_2 1.0382 - custo 6.0476
# ÉPOCA  315 finalizada: erro_0 11.4004 | erro_1 5.6287 | erro_2 1.0550 - custo 6.0280
# ÉPOCA  316 finalizada: erro_0 11.3396 | erro_1 5.6055 | erro_2 1.0682 - custo 6.0044
# ÉPOCA  317 finalizada: erro_0 11.4243 | erro_1 5.6353 | erro_2 1.0825 - custo 6.0474
# ÉPOCA  318 finalizada: erro_0 11.3003 | erro_1 5.5339 | erro_2 1.0493 - custo 5.9612
# ÉPOCA  319 finalizada: erro_0 11.3341 | erro_1 5.5849 | erro_2 1.0296 - custo 5.9829
# ÉPOCA  320 finalizada: erro_0 11.3607 | erro_1 5.5838 | erro_2 1.0675 - custo 6.0040
# ÉPOCA  321 finalizada: erro_0 11.3317 | erro_1 5.5918 | erro_2 1.0607 - custo 5.9947
# ÉPOCA  322 finalizada: erro_0 11.2167 | erro_1 5.5343 | erro_2 1.0275 - custo 5.9261
# ÉPOCA  323 finalizada: erro_0 11.2343 | erro_1 5.5367 | erro_2 1.0218 - custo 5.9310
# ÉPOCA  324 finalizada: erro_0 11.2459 | erro_1 5.5707 | erro_2 1.0344 - custo 5.9503
# ÉPOCA  325 finalizada: erro_0 11.2743 | erro_1 5.5236 | erro_2 1.0165 - custo 5.9381
# ÉPOCA  326 finalizada: erro_0 11.2970 | erro_1 5.5701 | erro_2 1.0418 - custo 5.9696
# ÉPOCA  327 finalizada: erro_0 11.4309 | erro_1 5.5950 | erro_2 1.0150 - custo 6.0136
# ÉPOCA  328 finalizada: erro_0 11.3231 | erro_1 5.5813 | erro_2 1.0158 - custo 5.9734
# ÉPOCA  329 finalizada: erro_0 11.2793 | erro_1 5.5817 | erro_2 1.0135 - custo 5.9582
# ÉPOCA  330 finalizada: erro_0 11.4519 | erro_1 5.6338 | erro_2 1.0050 - custo 6.0302
# ÉPOCA  331 finalizada: erro_0 11.3132 | erro_1 5.5098 | erro_2 1.0091 - custo 5.9440
# ÉPOCA  332 finalizada: erro_0 11.2276 | erro_1 5.5594 | erro_2 1.0251 - custo 5.9373
# ÉPOCA  333 finalizada: erro_0 11.1966 | erro_1 5.5543 | erro_2 1.0426 - custo 5.9312
# ÉPOCA  334 finalizada: erro_0 11.2384 | erro_1 5.5031 | erro_2 1.0013 - custo 5.9143
# ÉPOCA  335 finalizada: erro_0 11.3185 | erro_1 5.5511 | erro_2 1.0248 - custo 5.9648
# ÉPOCA  336 finalizada: erro_0 11.3140 | erro_1 5.6059 | erro_2 1.0465 - custo 5.9888
# ÉPOCA  337 finalizada: erro_0 11.1590 | erro_1 5.5081 | erro_2 1.0309 - custo 5.8993
# ÉPOCA  338 finalizada: erro_0 11.3211 | erro_1 5.5486 | erro_2 1.0413 - custo 5.9703
# ÉPOCA  339 finalizada: erro_0 11.6071 | erro_1 5.6637 | erro_2 1.0740 - custo 6.1149
# ÉPOCA  340 finalizada: erro_0 11.3516 | erro_1 5.4972 | erro_2 1.0341 - custo 5.9610
# ÉPOCA  341 finalizada: erro_0 11.5154 | erro_1 5.7116 | erro_2 1.1848 - custo 6.1373
# ÉPOCA  342 finalizada: erro_0 11.6868 | erro_1 5.7584 | erro_2 1.1611 - custo 6.2021
# ÉPOCA  343 finalizada: erro_0 11.4800 | erro_1 5.6022 | erro_2 1.0608 - custo 6.0477
# ÉPOCA  344 finalizada: erro_0 11.3932 | erro_1 5.5892 | erro_2 1.0929 - custo 6.0251
# ÉPOCA  345 finalizada: erro_0 11.4059 | erro_1 5.6129 | erro_2 1.0844 - custo 6.0344
# ÉPOCA  346 finalizada: erro_0 11.3977 | erro_1 5.6194 | erro_2 1.0628 - custo 6.0266
# ÉPOCA  347 finalizada: erro_0 11.3788 | erro_1 5.6115 | erro_2 1.0749 - custo 6.0217
# ÉPOCA  348 finalizada: erro_0 11.3509 | erro_1 5.5643 | erro_2 1.0897 - custo 6.0016
# ÉPOCA  349 finalizada: erro_0 11.5950 | erro_1 5.7672 | erro_2 1.1365 - custo 6.1662
# ÉPOCA  350 finalizada: erro_0 11.4570 | erro_1 5.6002 | erro_2 1.0566 - custo 6.0379
# ÉPOCA  351 finalizada: erro_0 11.4411 | erro_1 5.6450 | erro_2 1.0789 - custo 6.0550
# ÉPOCA  352 finalizada: erro_0 11.5304 | erro_1 5.6947 | erro_2 1.0908 - custo 6.1053
# ÉPOCA  353 finalizada: erro_0 11.3025 | erro_1 5.5785 | erro_2 1.0531 - custo 5.9780
# ÉPOCA  354 finalizada: erro_0 11.1775 | erro_1 5.6163 | erro_2 1.0974 - custo 5.9637
# ÉPOCA  355 finalizada: erro_0 11.3859 | erro_1 5.6564 | erro_2 1.0837 - custo 6.0420
# ÉPOCA  356 finalizada: erro_0 11.3428 | erro_1 5.6081 | erro_2 1.0640 - custo 6.0050
# ÉPOCA  357 finalizada: erro_0 11.2991 | erro_1 5.5780 | erro_2 1.0566 - custo 5.9779
# ÉPOCA  358 finalizada: erro_0 11.3106 | erro_1 5.5854 | erro_2 1.0625 - custo 5.9862
# ÉPOCA  359 finalizada: erro_0 11.2680 | erro_1 5.5527 | erro_2 1.0601 - custo 5.9603
# ÉPOCA  360 finalizada: erro_0 11.3136 | erro_1 5.5937 | erro_2 1.0564 - custo 5.9879
# ÉPOCA  361 finalizada: erro_0 11.4142 | erro_1 5.6237 | erro_2 1.1158 - custo 6.0512
# ÉPOCA  362 finalizada: erro_0 11.3683 | erro_1 5.6199 | erro_2 1.1300 - custo 6.0394
# ÉPOCA  363 finalizada: erro_0 11.8019 | erro_1 5.7186 | erro_2 1.1201 - custo 6.2135
# ÉPOCA  364 finalizada: erro_0 11.4042 | erro_1 5.6366 | erro_2 1.0925 - custo 6.0444
# ÉPOCA  365 finalizada: erro_0 11.3450 | erro_1 5.5758 | erro_2 1.0870 - custo 6.0026
# ÉPOCA  366 finalizada: erro_0 11.2623 | erro_1 5.5322 | erro_2 1.0661 - custo 5.9536
# ÉPOCA  367 finalizada: erro_0 11.4822 | erro_1 5.6269 | erro_2 1.0716 - custo 6.0602
# ÉPOCA  368 finalizada: erro_0 11.2780 | erro_1 5.5193 | erro_2 1.0359 - custo 5.9444
# ÉPOCA  369 finalizada: erro_0 11.2483 | erro_1 5.5175 | erro_2 1.0340 - custo 5.9333
# ÉPOCA  370 finalizada: erro_0 11.2808 | erro_1 5.5871 | erro_2 1.1171 - custo 5.9950
# ÉPOCA  371 finalizada: erro_0 11.6686 | erro_1 5.7101 | erro_2 1.1296 - custo 6.1694
# ÉPOCA  372 finalizada: erro_0 11.4063 | erro_1 5.5947 | erro_2 1.0425 - custo 6.0145
# ÉPOCA  373 finalizada: erro_0 11.1917 | erro_1 5.4923 | erro_2 1.0407 - custo 5.9082
# ÉPOCA  374 finalizada: erro_0 11.3928 | erro_1 5.6339 | erro_2 1.0887 - custo 6.0385
# ÉPOCA  375 finalizada: erro_0 11.2962 | erro_1 5.4749 | erro_2 1.0084 - custo 5.9265
# ÉPOCA  376 finalizada: erro_0 11.2150 | erro_1 5.4899 | erro_2 1.0535 - custo 5.9194
# ÉPOCA  377 finalizada: erro_0 11.2646 | erro_1 5.5052 | erro_2 1.0595 - custo 5.9431
# ÉPOCA  378 finalizada: erro_0 11.1596 | erro_1 5.4757 | erro_2 1.0528 - custo 5.8960
# ÉPOCA  379 finalizada: erro_0 11.2840 | erro_1 5.5347 | erro_2 1.0229 - custo 5.9472
# ÉPOCA  380 finalizada: erro_0 11.3215 | erro_1 5.5549 | erro_2 1.0581 - custo 5.9782
# ÉPOCA  381 finalizada: erro_0 11.2367 | erro_1 5.5476 | erro_2 1.0694 - custo 5.9512
# ÉPOCA  382 finalizada: erro_0 11.3566 | erro_1 5.5600 | erro_2 1.0173 - custo 5.9779
# ÉPOCA  383 finalizada: erro_0 11.2139 | erro_1 5.4814 | erro_2 1.0032 - custo 5.8995
# ÉPOCA  384 finalizada: erro_0 11.2607 | erro_1 5.5133 | erro_2 1.0634 - custo 5.9458
# ÉPOCA  385 finalizada: erro_0 11.3060 | erro_1 5.5712 | erro_2 1.0427 - custo 5.9733
# ÉPOCA  386 finalizada: erro_0 11.1910 | erro_1 5.5110 | erro_2 1.0469 - custo 5.9163
# ÉPOCA  387 finalizada: erro_0 11.3622 | erro_1 5.6167 | erro_2 1.0943 - custo 6.0244
# ÉPOCA  388 finalizada: erro_0 11.1957 | erro_1 5.5689 | erro_2 1.0529 - custo 5.9392
# ÉPOCA  389 finalizada: erro_0 11.0638 | erro_1 5.4785 | erro_2 1.0473 - custo 5.8632
# ÉPOCA  390 finalizada: erro_0 11.9488 | erro_1 5.9543 | erro_2 1.1520 - custo 6.3517
# ÉPOCA  391 finalizada: erro_0 11.2823 | erro_1 5.5314 | erro_2 1.0451 - custo 5.9529
# ÉPOCA  392 finalizada: erro_0 11.2206 | erro_1 5.5425 | erro_2 1.0664 - custo 5.9432
# ÉPOCA  393 finalizada: erro_0 11.4041 | erro_1 5.6362 | erro_2 1.0583 - custo 6.0329
# ÉPOCA  394 finalizada: erro_0 11.0474 | erro_1 5.4636 | erro_2 1.0817 - custo 5.8642
# ÉPOCA  395 finalizada: erro_0 11.1358 | erro_1 5.5375 | erro_2 1.1236 - custo 5.9323
# ÉPOCA  396 finalizada: erro_0 11.1351 | erro_1 5.4662 | erro_2 1.0622 - custo 5.8878
# ÉPOCA  397 finalizada: erro_0 11.3255 | erro_1 5.5341 | erro_2 1.0357 - custo 5.9651
# ÉPOCA  398 finalizada: erro_0 11.2700 | erro_1 5.5212 | erro_2 1.0815 - custo 5.9575
# ÉPOCA  399 finalizada: erro_0 11.5086 | erro_1 5.6070 | erro_2 1.0548 - custo 6.0568
# ÉPOCA  400 finalizada: erro_0 11.2598 | erro_1 5.4762 | erro_2 1.0394 - custo 5.9251
# ÉPOCA  401 finalizada: erro_0 11.1613 | erro_1 5.4743 | erro_2 1.0272 - custo 5.8876
# ÉPOCA  402 finalizada: erro_0 10.9715 | erro_1 5.4393 | erro_2 1.0484 - custo 5.8197
# ÉPOCA  403 finalizada: erro_0 11.0928 | erro_1 5.4549 | erro_2 1.0334 - custo 5.8603
# ÉPOCA  404 finalizada: erro_0 11.1873 | erro_1 5.5367 | erro_2 1.0978 - custo 5.9406
# ÉPOCA  405 finalizada: erro_0 11.3300 | erro_1 5.5332 | erro_2 1.0282 - custo 5.9638
# ÉPOCA  406 finalizada: erro_0 11.2839 | erro_1 5.4847 | erro_2 1.0184 - custo 5.9290
# ÉPOCA  407 finalizada: erro_0 11.2176 | erro_1 5.5024 | erro_2 1.0301 - custo 5.9167
# ÉPOCA  408 finalizada: erro_0 11.0391 | erro_1 5.4730 | erro_2 1.0270 - custo 5.8464
# ÉPOCA  409 finalizada: erro_0 11.2301 | erro_1 5.4682 | erro_2 1.0210 - custo 5.9065
# ÉPOCA  410 finalizada: erro_0 11.6878 | erro_1 5.6519 | erro_2 1.1377 - custo 6.1591
# ÉPOCA  411 finalizada: erro_0 11.2034 | erro_1 5.4962 | erro_2 1.0923 - custo 5.9307
# ÉPOCA  412 finalizada: erro_0 11.0980 | erro_1 5.5073 | erro_2 1.0474 - custo 5.8843
# ÉPOCA  413 finalizada: erro_0 11.0042 | erro_1 5.4042 | erro_2 1.0300 - custo 5.8128
# ÉPOCA  414 finalizada: erro_0 11.1782 | erro_1 5.5128 | erro_2 1.0096 - custo 5.9002
# ÉPOCA  415 finalizada: erro_0 11.1768 | erro_1 5.4902 | erro_2 1.0473 - custo 5.9047
# ÉPOCA  416 finalizada: erro_0 11.0278 | erro_1 5.4049 | erro_2 1.0172 - custo 5.8166
# ÉPOCA  417 finalizada: erro_0 11.0785 | erro_1 5.4652 | erro_2 1.0347 - custo 5.8595
# ÉPOCA  418 finalizada: erro_0 11.0205 | erro_1 5.4155 | erro_2 1.0215 - custo 5.8191
# ÉPOCA  419 finalizada: erro_0 10.9394 | erro_1 5.4300 | erro_2 1.0383 - custo 5.8025
# ÉPOCA  420 finalizada: erro_0 10.9579 | erro_1 5.3939 | erro_2 1.0182 - custo 5.7900
# ÉPOCA  421 finalizada: erro_0 11.0027 | erro_1 5.4858 | erro_2 1.0715 - custo 5.8533
# ÉPOCA  422 finalizada: erro_0 11.0164 | erro_1 5.4403 | erro_2 1.0703 - custo 5.8424
# ÉPOCA  423 finalizada: erro_0 11.3144 | erro_1 5.5471 | erro_2 1.0471 - custo 5.9695
# ÉPOCA  424 finalizada: erro_0 11.1335 | erro_1 5.4605 | erro_2 1.0682 - custo 5.8874
# ÉPOCA  425 finalizada: erro_0 10.9661 | erro_1 5.3978 | erro_2 1.0047 - custo 5.7895
# ÉPOCA  426 finalizada: erro_0 11.4216 | erro_1 5.5828 | erro_2 1.1652 - custo 6.0565
# ÉPOCA  427 finalizada: erro_0 11.6527 | erro_1 5.5918 | erro_2 1.0921 - custo 6.1122
# ÉPOCA  428 finalizada: erro_0 11.3263 | erro_1 5.4946 | erro_2 1.0332 - custo 5.9514
# ÉPOCA  429 finalizada: erro_0 11.1451 | erro_1 5.4716 | erro_2 1.0159 - custo 5.8775
# ÉPOCA  430 finalizada: erro_0 11.0414 | erro_1 5.3653 | erro_2 1.0193 - custo 5.8087
# ÉPOCA  431 finalizada: erro_0 11.0019 | erro_1 5.3587 | erro_2 1.0024 - custo 5.7877
# ÉPOCA  432 finalizada: erro_0 11.0173 | erro_1 5.4504 | erro_2 1.0400 - custo 5.8359
# ÉPOCA  433 finalizada: erro_0 11.0508 | erro_1 5.4398 | erro_2 1.0244 - custo 5.8383
# ÉPOCA  434 finalizada: erro_0 11.4111 | erro_1 5.5361 | erro_2 1.0715 - custo 6.0062
# ÉPOCA  435 finalizada: erro_0 11.2396 | erro_1 5.4326 | erro_2 1.0008 - custo 5.8910
# ÉPOCA  436 finalizada: erro_0 11.0662 | erro_1 5.4255 | erro_2 1.0355 - custo 5.8424
# ÉPOCA  437 finalizada: erro_0 11.2339 | erro_1 5.5794 | erro_2 1.0418 - custo 5.9517
# ÉPOCA  438 finalizada: erro_0 11.2862 | erro_1 5.4578 | erro_2 1.0289 - custo 5.9243
# ÉPOCA  439 finalizada: erro_0 11.2287 | erro_1 5.4783 | erro_2 1.0858 - custo 5.9309
# ÉPOCA  440 finalizada: erro_0 11.2177 | erro_1 5.4899 | erro_2 1.0572 - custo 5.9216
# ÉPOCA  441 finalizada: erro_0 11.4038 | erro_1 5.5538 | erro_2 1.0593 - custo 6.0056
# ÉPOCA  442 finalizada: erro_0 11.0043 | erro_1 5.3525 | erro_2 1.0229 - custo 5.7933
# ÉPOCA  443 finalizada: erro_0 10.9634 | erro_1 5.3693 | erro_2 1.0148 - custo 5.7825
# ÉPOCA  444 finalizada: erro_0 11.2935 | erro_1 5.4844 | erro_2 1.0559 - custo 5.9446
# ÉPOCA  445 finalizada: erro_0 10.8538 | erro_1 5.4052 | erro_2 1.0603 - custo 5.7731
# ÉPOCA  446 finalizada: erro_0 10.9141 | erro_1 5.3312 | erro_2 1.0151 - custo 5.7535
# ÉPOCA  447 finalizada: erro_0 11.0220 | erro_1 5.3825 | erro_2 1.0012 - custo 5.8019
# ÉPOCA  448 finalizada: erro_0 11.1010 | erro_1 5.4416 | erro_2 1.0296 - custo 5.8574
# ÉPOCA  449 finalizada: erro_0 10.8614 | erro_1 5.3463 | erro_2 1.0033 - custo 5.7370
# ÉPOCA  450 finalizada: erro_0 11.0511 | erro_1 5.3728 | erro_2 1.0055 - custo 5.8098
# ÉPOCA  451 finalizada: erro_0 10.8807 | erro_1 5.3585 | erro_2 1.0183 - custo 5.7525
# ÉPOCA  452 finalizada: erro_0 10.8374 | erro_1 5.3344 | erro_2 1.0059 - custo 5.7259
# ÉPOCA  453 finalizada: erro_0 11.0634 | erro_1 5.4538 | erro_2 1.0459 - custo 5.8543
# ÉPOCA  454 finalizada: erro_0 10.9339 | erro_1 5.3615 | erro_2 1.0309 - custo 5.7754
# ÉPOCA  455 finalizada: erro_0 11.1475 | erro_1 5.4236 | erro_2 1.0202 - custo 5.8638
# ÉPOCA  456 finalizada: erro_0 11.3501 | erro_1 5.5649 | erro_2 1.0546 - custo 5.9899
# ÉPOCA  457 finalizada: erro_0 10.9995 | erro_1 5.3838 | erro_2 1.0108 - custo 5.7981
# ÉPOCA  458 finalizada: erro_0 11.1409 | erro_1 5.4391 | erro_2 1.0760 - custo 5.8853
# ÉPOCA  459 finalizada: erro_0 10.9815 | erro_1 5.3964 | erro_2 1.0559 - custo 5.8113
# ÉPOCA  460 finalizada: erro_0 10.9687 | erro_1 5.4004 | erro_2 1.0060 - custo 5.7917
# ÉPOCA  461 finalizada: erro_0 10.8221 | erro_1 5.3571 | erro_2 1.0327 - custo 5.7373
# ÉPOCA  462 finalizada: erro_0 10.7944 | erro_1 5.3798 | erro_2 1.0037 - custo 5.7260
# ÉPOCA  463 finalizada: erro_0 10.7240 | erro_1 5.3205 | erro_2 0.9902 - custo 5.6782
# ÉPOCA  464 finalizada: erro_0 10.8629 | erro_1 5.3635 | erro_2 0.9894 - custo 5.7386
# ÉPOCA  465 finalizada: erro_0 10.8725 | erro_1 5.4092 | erro_2 1.0724 - custo 5.7847
# ÉPOCA  466 finalizada: erro_0 11.0459 | erro_1 5.5262 | erro_2 1.0485 - custo 5.8735
# ÉPOCA  467 finalizada: erro_0 10.9142 | erro_1 5.3094 | erro_2 0.9852 - custo 5.7363
# ÉPOCA  468 finalizada: erro_0 10.7684 | erro_1 5.2748 | erro_2 0.9669 - custo 5.6700
# ÉPOCA  469 finalizada: erro_0 10.7187 | erro_1 5.3895 | erro_2 1.0218 - custo 5.7100
# ÉPOCA  470 finalizada: erro_0 10.8718 | erro_1 5.4225 | erro_2 1.0051 - custo 5.7664
# ÉPOCA  471 finalizada: erro_0 10.8175 | erro_1 5.3220 | erro_2 0.9687 - custo 5.7027
# ÉPOCA  472 finalizada: erro_0 10.8309 | erro_1 5.3422 | erro_2 1.0580 - custo 5.7437
# ÉPOCA  473 finalizada: erro_0 10.8747 | erro_1 5.3377 | erro_2 1.0402 - custo 5.7509
# ÉPOCA  474 finalizada: erro_0 11.1301 | erro_1 5.3850 | erro_2 1.0189 - custo 5.8447
# ÉPOCA  475 finalizada: erro_0 10.8438 | erro_1 5.3291 | erro_2 1.0440 - custo 5.7390
# ÉPOCA  476 finalizada: erro_0 10.6805 | erro_1 5.2694 | erro_2 1.0408 - custo 5.6635
# ÉPOCA  477 finalizada: erro_0 10.7823 | erro_1 5.2782 | erro_2 1.0424 - custo 5.7010
# ÉPOCA  478 finalizada: erro_0 10.7473 | erro_1 5.3568 | erro_2 1.1272 - custo 5.7438
# ÉPOCA  479 finalizada: erro_0 10.8537 | erro_1 5.2472 | erro_2 1.0269 - custo 5.7093
# ÉPOCA  480 finalizada: erro_0 10.8916 | erro_1 5.3924 | erro_2 1.0539 - custo 5.7793
# ÉPOCA  481 finalizada: erro_0 10.9392 | erro_1 5.2940 | erro_2 1.0369 - custo 5.7567
# ÉPOCA  482 finalizada: erro_0 10.9254 | erro_1 5.2941 | erro_2 1.0602 - custo 5.7599
# ÉPOCA  483 finalizada: erro_0 11.0850 | erro_1 5.3049 | erro_2 1.0223 - custo 5.8041
# ÉPOCA  484 finalizada: erro_0 10.9178 | erro_1 5.4009 | erro_2 1.0790 - custo 5.7993
# ÉPOCA  485 finalizada: erro_0 10.7706 | erro_1 5.2691 | erro_2 1.0318 - custo 5.6905
# ÉPOCA  486 finalizada: erro_0 10.9328 | erro_1 5.3727 | erro_2 1.0734 - custo 5.7929
# ÉPOCA  487 finalizada: erro_0 10.8033 | erro_1 5.2386 | erro_2 1.0318 - custo 5.6913
# ÉPOCA  488 finalizada: erro_0 10.8076 | erro_1 5.2707 | erro_2 1.0322 - custo 5.7035
# ÉPOCA  489 finalizada: erro_0 10.8449 | erro_1 5.2445 | erro_2 1.0382 - custo 5.7092
# ÉPOCA  490 finalizada: erro_0 10.7872 | erro_1 5.4279 | erro_2 1.0458 - custo 5.7536
# ÉPOCA  491 finalizada: erro_0 11.0863 | erro_1 5.3646 | erro_2 1.0161 - custo 5.8224
# ÉPOCA  492 finalizada: erro_0 10.7606 | erro_1 5.2881 | erro_2 1.0719 - custo 5.7069
# ÉPOCA  493 finalizada: erro_0 10.8570 | erro_1 5.2743 | erro_2 1.0856 - custo 5.7390
# ÉPOCA  494 finalizada: erro_0 10.7487 | erro_1 5.1917 | erro_2 1.0518 - custo 5.6641
# ÉPOCA  495 finalizada: erro_0 10.7144 | erro_1 5.2604 | erro_2 1.0954 - custo 5.6901
# ÉPOCA  496 finalizada: erro_0 10.7634 | erro_1 5.2340 | erro_2 1.0759 - custo 5.6911
# ÉPOCA  497 finalizada: erro_0 10.6301 | erro_1 5.2370 | erro_2 1.0773 - custo 5.6482
# ÉPOCA  498 finalizada: erro_0 10.5945 | erro_1 5.1460 | erro_2 1.0672 - custo 5.6026
# ÉPOCA  499 finalizada: erro_0 10.5611 | erro_1 5.2437 | erro_2 1.0953 - custo 5.6334
# ÉPOCA  500 finalizada: erro_0 10.6741 | erro_1 5.1881 | erro_2 1.0591 - custo 5.6404
# ÉPOCA  501 finalizada: erro_0 10.6240 | erro_1 5.2110 | erro_2 1.0758 - custo 5.6369
# ÉPOCA  502 finalizada: erro_0 10.6104 | erro_1 5.2398 | erro_2 1.0798 - custo 5.6434
# ÉPOCA  503 finalizada: erro_0 10.9683 | erro_1 5.2859 | erro_2 1.0793 - custo 5.7778
# ÉPOCA  504 finalizada: erro_0 10.6393 | erro_1 5.1434 | erro_2 1.0464 - custo 5.6097
# ÉPOCA  505 finalizada: erro_0 10.6703 | erro_1 5.1702 | erro_2 1.0629 - custo 5.6345
# ÉPOCA  506 finalizada: erro_0 10.5922 | erro_1 5.1969 | erro_2 1.0670 - custo 5.6187
# ÉPOCA  507 finalizada: erro_0 10.5991 | erro_1 5.1805 | erro_2 1.0681 - custo 5.6159
# ÉPOCA  508 finalizada: erro_0 10.5732 | erro_1 5.1435 | erro_2 1.0801 - custo 5.5989
# ÉPOCA  509 finalizada: erro_0 11.2364 | erro_1 5.4180 | erro_2 1.0776 - custo 5.9106
# ÉPOCA  510 finalizada: erro_0 10.5910 | erro_1 5.2629 | erro_2 1.0960 - custo 5.6500
# ...
# ÉPOCA 1831 finalizada: erro_0 10.5772 | erro_1 5.1754 | erro_2 0.9738 - custo 5.5755
# ÉPOCA 1832 finalizada: erro_0 11.5016 | erro_1 5.6255 | erro_2 1.1363 - custo 6.0878
# ÉPOCA 1833 finalizada: erro_0 10.6441 | erro_1 5.2010 | erro_2 0.9501 - custo 5.5984
# ÉPOCA 1834 finalizada: erro_0 11.4939 | erro_1 5.5475 | erro_2 1.0924 - custo 6.0446
# ÉPOCA 1835 finalizada: erro_0 12.7448 | erro_1 6.2114 | erro_2 1.1706 - custo 6.7089
# ÉPOCA 1836 finalizada: erro_0 10.9786 | erro_1 5.3555 | erro_2 1.0502 - custo 5.7948
# ÉPOCA 1837 finalizada: erro_0 10.7398 | erro_1 5.2022 | erro_2 0.9485 - custo 5.6302
# ÉPOCA 1838 finalizada: erro_0 10.7625 | erro_1 5.2575 | erro_2 1.0277 - custo 5.6826
# ÉPOCA 1839 finalizada: erro_0 10.9263 | erro_1 5.3184 | erro_2 0.9729 - custo 5.7392
# ÉPOCA 1840 finalizada: erro_0 10.6903 | erro_1 5.1801 | erro_2 0.9140 - custo 5.5948
# ÉPOCA 1841 finalizada: erro_0 10.5846 | erro_1 5.1551 | erro_2 1.0084 - custo 5.5827
# ÉPOCA 1842 finalizada: erro_0 10.5459 | erro_1 5.1137 | erro_2 0.9721 - custo 5.5439
# ÉPOCA 1843 finalizada: erro_0 10.4717 | erro_1 5.1124 | erro_2 1.0066 - custo 5.5302
# ÉPOCA 1844 finalizada: erro_0 10.8805 | erro_1 5.2574 | erro_2 1.0590 - custo 5.7323
# ÉPOCA 1845 finalizada: erro_0 10.4059 | erro_1 5.0940 | erro_2 1.0100 - custo 5.5033
# ÉPOCA 1846 finalizada: erro_0 10.2306 | erro_1 4.9566 | erro_2 1.0240 - custo 5.4037
# ÉPOCA 1847 finalizada: erro_0 12.3327 | erro_1 6.3293 | erro_2 1.2380 - custo 6.6334
# ÉPOCA 1848 finalizada: erro_0 12.5622 | erro_1 6.1408 | erro_2 1.1278 - custo 6.6103
# ÉPOCA 1849 finalizada: erro_0 11.0582 | erro_1 5.4927 | erro_2 1.0522 - custo 5.8677
# ÉPOCA 1850 finalizada: erro_0 10.7161 | erro_1 5.3241 | erro_2 0.9720 - custo 5.6707
# ÉPOCA 1851 finalizada: erro_0 10.7430 | erro_1 5.2484 | erro_2 0.9324 - custo 5.6413
# ÉPOCA 1852 finalizada: erro_0 10.5621 | erro_1 5.1541 | erro_2 1.0040 - custo 5.5734
# ÉPOCA 1853 finalizada: erro_0 10.5222 | erro_1 5.1224 | erro_2 0.9889 - custo 5.5445
# ÉPOCA 1854 finalizada: erro_0 10.4733 | erro_1 5.1105 | erro_2 1.0053 - custo 5.5297
# ÉPOCA 1855 finalizada: erro_0 10.3177 | erro_1 5.0852 | erro_2 1.0046 - custo 5.4692
# ÉPOCA 1856 finalizada: erro_0 10.3471 | erro_1 5.1343 | erro_2 1.0384 - custo 5.5066
# ÉPOCA 1857 finalizada: erro_0 12.0922 | erro_1 5.9216 | erro_2 1.0462 - custo 6.3533
# ÉPOCA 1858 finalizada: erro_0 10.5642 | erro_1 5.1319 | erro_2 1.0109 - custo 5.5690
# ÉPOCA 1859 finalizada: erro_0 10.4332 | erro_1 5.0872 | erro_2 0.9625 - custo 5.4943
# ÉPOCA 1860 finalizada: erro_0 10.4914 | erro_1 5.1397 | erro_2 1.0293 - custo 5.5535
# ÉPOCA 1861 finalizada: erro_0 10.3301 | erro_1 5.0389 | erro_2 0.9860 - custo 5.4517
# ÉPOCA 1862 finalizada: erro_0 10.4731 | erro_1 5.0759 | erro_2 0.9943 - custo 5.5145
# ÉPOCA 1863 finalizada: erro_0 10.3073 | erro_1 5.0082 | erro_2 0.9771 - custo 5.4308
# ÉPOCA 1864 finalizada: erro_0 10.5673 | erro_1 5.1057 | erro_2 0.9198 - custo 5.5309
# ÉPOCA 1865 finalizada: erro_0 10.3821 | erro_1 4.9780 | erro_2 0.8876 - custo 5.4159
# ÉPOCA 1866 finalizada: erro_0 11.3690 | erro_1 5.5606 | erro_2 1.0440 - custo 5.9912
# ÉPOCA 1867 finalizada: erro_0 10.5885 | erro_1 5.1010 | erro_2 0.9891 - custo 5.5596
# ÉPOCA 1868 finalizada: erro_0 10.6216 | erro_1 5.0762 | erro_2 0.8861 - custo 5.5280
# ÉPOCA 1869 finalizada: erro_0 10.4273 | erro_1 5.0107 | erro_2 0.9394 - custo 5.4591
# ÉPOCA 1870 finalizada: erro_0 10.4676 | erro_1 5.0206 | erro_2 0.9427 - custo 5.4770
# ÉPOCA 1871 finalizada: erro_0 10.3538 | erro_1 4.9540 | erro_2 0.9248 - custo 5.4109
# ÉPOCA 1872 finalizada: erro_0 10.3521 | erro_1 4.9869 | erro_2 0.9476 - custo 5.4289
# ÉPOCA 1873 finalizada: erro_0 11.3616 | erro_1 5.5224 | erro_2 1.0589 - custo 5.9810
# ÉPOCA 1874 finalizada: erro_0 11.0288 | erro_1 5.4130 | erro_2 0.9404 - custo 5.7941
# ÉPOCA 1875 finalizada: erro_0 10.4163 | erro_1 4.9937 | erro_2 1.0262 - custo 5.4787
# ÉPOCA 1876 finalizada: erro_0 10.3557 | erro_1 4.9912 | erro_2 0.9511 - custo 5.4327
# ÉPOCA 1877 finalizada: erro_0 10.2543 | erro_1 4.9158 | erro_2 1.0340 - custo 5.4013
# ÉPOCA 1878 finalizada: erro_0 10.4346 | erro_1 5.0302 | erro_2 0.9981 - custo 5.4876
# ÉPOCA 1879 finalizada: erro_0 10.2408 | erro_1 4.9041 | erro_2 0.9463 - custo 5.3638
# ÉPOCA 1880 finalizada: erro_0 10.0208 | erro_1 4.8248 | erro_2 0.9129 - custo 5.2528
# ÉPOCA 1881 finalizada: erro_0 12.1126 | erro_1 5.9747 | erro_2 0.9974 - custo 6.3615
# ÉPOCA 1882 finalizada: erro_0 10.6106 | erro_1 5.0597 | erro_2 0.9872 - custo 5.5525
# ÉPOCA 1883 finalizada: erro_0 10.2519 | erro_1 4.9066 | erro_2 0.9422 - custo 5.3669
# ÉPOCA 1884 finalizada: erro_0 10.5022 | erro_1 5.0834 | erro_2 0.9569 - custo 5.5142
# ÉPOCA 1885 finalizada: erro_0 10.2787 | erro_1 4.9235 | erro_2 0.9867 - custo 5.3963
# ÉPOCA 1886 finalizada: erro_0 10.4338 | erro_1 4.9923 | erro_2 0.9792 - custo 5.4684
# ÉPOCA 1887 finalizada: erro_0 10.2204 | erro_1 4.9031 | erro_2 0.9868 - custo 5.3701
# ÉPOCA 1888 finalizada: erro_0 10.0754 | erro_1 4.7765 | erro_2 0.9111 - custo 5.2543
# ÉPOCA 1889 finalizada: erro_0 10.1344 | erro_1 4.8347 | erro_2 0.9681 - custo 5.3124
# ÉPOCA 1890 finalizada: erro_0 10.2509 | erro_1 4.9368 | erro_2 1.0014 - custo 5.3964
# ÉPOCA 1891 finalizada: erro_0 10.2955 | erro_1 4.9424 | erro_2 0.9341 - custo 5.3906
# ÉPOCA 1892 finalizada: erro_0 11.4442 | erro_1 5.6851 | erro_2 1.1547 - custo 6.0946
# ÉPOCA 1893 finalizada: erro_0 10.4376 | erro_1 4.9552 | erro_2 0.9082 - custo 5.4337
# ÉPOCA 1894 finalizada: erro_0 10.2992 | erro_1 4.8866 | erro_2 0.9677 - custo 5.3845
# ÉPOCA 1895 finalizada: erro_0 10.2732 | erro_1 4.8560 | erro_2 0.9216 - custo 5.3503
# ÉPOCA 1896 finalizada: erro_0 10.3491 | erro_1 4.9199 | erro_2 0.9459 - custo 5.4050
# ÉPOCA 1897 finalizada: erro_0 9.9934 | erro_1 4.7783 | erro_2 0.9700 - custo 5.2472
# ÉPOCA 1898 finalizada: erro_0 11.4029 | erro_1 5.5539 | erro_2 1.1269 - custo 6.0279
# ÉPOCA 1899 finalizada: erro_0 10.2627 | erro_1 4.8690 | erro_2 1.0224 - custo 5.3847
# ÉPOCA 1900 finalizada: erro_0 11.0371 | erro_1 5.2891 | erro_2 0.9760 - custo 5.7674
# ÉPOCA 1901 finalizada: erro_0 10.5772 | erro_1 4.8534 | erro_2 0.9702 - custo 5.4669
# ÉPOCA 1902 finalizada: erro_0 12.2187 | erro_1 5.8772 | erro_2 1.1406 - custo 6.4122
# ÉPOCA 1903 finalizada: erro_0 10.6310 | erro_1 5.0680 | erro_2 0.9844 - custo 5.5611
# ÉPOCA 1904 finalizada: erro_0 10.3583 | erro_1 4.9191 | erro_2 0.9637 - custo 5.4137
# ÉPOCA 1905 finalizada: erro_0 10.1711 | erro_1 4.8295 | erro_2 0.9666 - custo 5.3224
# ÉPOCA 1906 finalizada: erro_0 10.1920 | erro_1 4.8399 | erro_2 0.9396 - custo 5.3238
# ÉPOCA 1907 finalizada: erro_0 10.0499 | erro_1 4.7160 | erro_2 0.8955 - custo 5.2205
# ÉPOCA 1908 finalizada: erro_0 10.2366 | erro_1 4.9148 | erro_2 0.9738 - custo 5.3751
# ÉPOCA 1909 finalizada: erro_0 12.2523 | erro_1 5.8715 | erro_2 0.9895 - custo 6.3711
# ÉPOCA 1910 finalizada: erro_0 10.5585 | erro_1 5.0221 | erro_2 0.9668 - custo 5.5158
# ÉPOCA 1911 finalizada: erro_0 10.4018 | erro_1 4.9480 | erro_2 0.9652 - custo 5.4383
# ÉPOCA 1912 finalizada: erro_0 10.2033 | erro_1 4.8433 | erro_2 0.9624 - custo 5.3363
# ÉPOCA 1913 finalizada: erro_0 9.9877 | erro_1 4.7877 | erro_2 0.9896 - custo 5.2550
# ÉPOCA 1914 finalizada: erro_0 10.1871 | erro_1 4.8553 | erro_2 0.9620 - custo 5.3348
# ÉPOCA 1915 finalizada: erro_0 10.2092 | erro_1 4.8826 | erro_2 1.0428 - custo 5.3782
# ÉPOCA 1916 finalizada: erro_0 9.8353 | erro_1 4.6896 | erro_2 0.9906 - custo 5.1718
# ÉPOCA 1917 finalizada: erro_0 11.9040 | erro_1 6.0246 | erro_2 1.0359 - custo 6.3215
# ÉPOCA 1918 finalizada: erro_0 11.4740 | erro_1 5.6054 | erro_2 0.9817 - custo 6.0204
# ÉPOCA 1919 finalizada: erro_0 9.9234 | erro_1 4.8451 | erro_2 1.0159 - custo 5.2615
# ÉPOCA 1920 finalizada: erro_0 10.3557 | erro_1 4.9507 | erro_2 0.9165 - custo 5.4076
# ÉPOCA 1921 finalizada: erro_0 11.0405 | erro_1 5.4043 | erro_2 1.0342 - custo 5.8263
# ÉPOCA 1922 finalizada: erro_0 11.3138 | erro_1 5.6352 | erro_2 1.0870 - custo 6.0120
# ÉPOCA 1923 finalizada: erro_0 10.7848 | erro_1 5.0550 | erro_2 0.8577 - custo 5.5658
# ÉPOCA 1924 finalizada: erro_0 10.2376 | erro_1 4.8109 | erro_2 0.9107 - custo 5.3197
# ÉPOCA 1925 finalizada: erro_0 10.2827 | erro_1 4.8677 | erro_2 0.9628 - custo 5.3711
# ÉPOCA 1926 finalizada: erro_0 10.1686 | erro_1 4.7958 | erro_2 0.9664 - custo 5.3103
# ÉPOCA 1927 finalizada: erro_0 10.1963 | erro_1 4.7862 | erro_2 0.9536 - custo 5.3120
# ÉPOCA 1928 finalizada: erro_0 10.8425 | erro_1 5.3751 | erro_2 0.8765 - custo 5.6980
# ÉPOCA 1929 finalizada: erro_0 10.4345 | erro_1 4.9231 | erro_2 0.8466 - custo 5.4014
# ÉPOCA 1930 finalizada: erro_0 11.8767 | erro_1 5.9890 | erro_2 1.0168 - custo 6.2942
# ÉPOCA 1931 finalizada: erro_0 10.8995 | erro_1 5.2821 | erro_2 0.9065 - custo 5.6960
# ÉPOCA 1932 finalizada: erro_0 10.1697 | erro_1 4.8426 | erro_2 0.8929 - custo 5.3018
# ÉPOCA 1933 finalizada: erro_0 10.2599 | erro_1 4.9132 | erro_2 0.9265 - custo 5.3665
# ÉPOCA 1934 finalizada: erro_0 10.1662 | erro_1 4.8273 | erro_2 0.9694 - custo 5.3210
# ÉPOCA 1935 finalizada: erro_0 10.0836 | erro_1 4.7866 | erro_2 0.9208 - custo 5.2637
# ÉPOCA 1936 finalizada: erro_0 10.1858 | erro_1 4.8653 | erro_2 0.9780 - custo 5.3430
# ÉPOCA 1937 finalizada: erro_0 10.1157 | erro_1 4.7745 | erro_2 0.9538 - custo 5.2814
# ÉPOCA 1938 finalizada: erro_0 9.9960 | erro_1 4.7395 | erro_2 0.9586 - custo 5.2314
# ÉPOCA 1939 finalizada: erro_0 9.9420 | erro_1 4.7572 | erro_2 1.0138 - custo 5.2377
# ÉPOCA 1940 finalizada: erro_0 11.0385 | erro_1 5.3885 | erro_2 0.9579 - custo 5.7950
# ÉPOCA 1941 finalizada: erro_0 10.0207 | erro_1 4.7664 | erro_2 0.9921 - custo 5.2598
# ÉPOCA 1942 finalizada: erro_0 10.0812 | erro_1 4.7780 | erro_2 0.9100 - custo 5.2564
# ÉPOCA 1943 finalizada: erro_0 9.9451 | erro_1 4.6506 | erro_2 0.9533 - custo 5.1830
# ÉPOCA 1944 finalizada: erro_0 10.0174 | erro_1 4.7937 | erro_2 0.9688 - custo 5.2600
# ÉPOCA 1945 finalizada: erro_0 9.9535 | erro_1 4.8915 | erro_2 0.9702 - custo 5.2717
# ÉPOCA 1946 finalizada: erro_0 11.1215 | erro_1 5.3266 | erro_2 0.9994 - custo 5.8158
# ÉPOCA 1947 finalizada: erro_0 11.6757 | erro_1 5.7037 | erro_2 0.9324 - custo 6.1039
# ÉPOCA 1948 finalizada: erro_0 10.1820 | erro_1 4.8135 | erro_2 0.9372 - custo 5.3109
# ÉPOCA 1949 finalizada: erro_0 10.0045 | erro_1 4.7174 | erro_2 0.9403 - custo 5.2207
# ÉPOCA 1950 finalizada: erro_0 10.0323 | erro_1 4.7184 | erro_2 0.8777 - custo 5.2095
# ÉPOCA 1951 finalizada: erro_0 10.7104 | erro_1 5.1474 | erro_2 0.9485 - custo 5.6021
# ÉPOCA 1952 finalizada: erro_0 11.8987 | erro_1 5.9762 | erro_2 0.9995 - custo 6.2915
# ÉPOCA 1953 finalizada: erro_0 10.3293 | erro_1 4.9327 | erro_2 1.0112 - custo 5.4244
# ÉPOCA 1954 finalizada: erro_0 10.0561 | erro_1 4.7925 | erro_2 0.9845 - custo 5.2777
# ÉPOCA 1955 finalizada: erro_0 10.0266 | erro_1 4.7677 | erro_2 0.9645 - custo 5.2529
# ÉPOCA 1956 finalizada: erro_0 9.7802 | erro_1 4.6671 | erro_2 0.9694 - custo 5.1389
# ÉPOCA 1957 finalizada: erro_0 10.3950 | erro_1 4.9860 | erro_2 0.9744 - custo 5.4518
# ÉPOCA 1958 finalizada: erro_0 13.2420 | erro_1 6.6910 | erro_2 1.3380 - custo 7.0903
# ÉPOCA 1959 finalizada: erro_0 11.3109 | erro_1 5.9083 | erro_2 1.2592 - custo 6.1595
# ÉPOCA 1960 finalizada: erro_0 10.6901 | erro_1 5.5292 | erro_2 1.1586 - custo 5.7927
# ÉPOCA 1961 finalizada: erro_0 10.4502 | erro_1 5.2595 | erro_2 1.0383 - custo 5.5827
# ÉPOCA 1962 finalizada: erro_0 10.5789 | erro_1 5.4232 | erro_2 1.0255 - custo 5.6759
# ÉPOCA 1963 finalizada: erro_0 10.4842 | erro_1 5.4130 | erro_2 1.0255 - custo 5.6409
# ÉPOCA 1964 finalizada: erro_0 10.3081 | erro_1 5.2091 | erro_2 0.9967 - custo 5.5046
# ÉPOCA 1965 finalizada: erro_0 10.1972 | erro_1 5.0165 | erro_2 0.9998 - custo 5.4045
# ÉPOCA 1966 finalizada: erro_0 10.1910 | erro_1 4.9094 | erro_2 0.9749 - custo 5.3584
# ÉPOCA 1967 finalizada: erro_0 10.1474 | erro_1 4.8531 | erro_2 0.9153 - custo 5.3053
# ÉPOCA 1968 finalizada: erro_0 10.3740 | erro_1 4.9307 | erro_2 0.9573 - custo 5.4207
# ÉPOCA 1969 finalizada: erro_0 10.9154 | erro_1 5.3180 | erro_2 0.8648 - custo 5.6994
# ÉPOCA 1970 finalizada: erro_0 10.3169 | erro_1 4.9391 | erro_2 0.9553 - custo 5.4038
# ÉPOCA 1971 finalizada: erro_0 10.1350 | erro_1 4.8276 | erro_2 0.9476 - custo 5.3034
# ÉPOCA 1972 finalizada: erro_0 10.0506 | erro_1 4.7965 | erro_2 0.9608 - custo 5.2693
# ÉPOCA 1973 finalizada: erro_0 9.8875 | erro_1 4.7293 | erro_2 0.9573 - custo 5.1914
# ÉPOCA 1974 finalizada: erro_0 9.9387 | erro_1 4.7336 | erro_2 0.9572 - custo 5.2098
# ÉPOCA 1975 finalizada: erro_0 10.0383 | erro_1 4.7892 | erro_2 0.9138 - custo 5.2471
# ÉPOCA 1976 finalizada: erro_0 9.8170 | erro_1 4.6597 | erro_2 0.9570 - custo 5.1446
# ÉPOCA 1977 finalizada: erro_0 10.0219 | erro_1 4.8018 | erro_2 0.9386 - custo 5.2541
# ÉPOCA 1978 finalizada: erro_0 11.9725 | erro_1 6.0018 | erro_2 0.9738 - custo 6.3161
# ÉPOCA 1979 finalizada: erro_0 10.2847 | erro_1 4.9387 | erro_2 1.0319 - custo 5.4184
# ÉPOCA 1980 finalizada: erro_0 10.0217 | erro_1 4.7733 | erro_2 0.9219 - custo 5.2390
# ÉPOCA 1981 finalizada: erro_0 9.9399 | erro_1 4.6895 | erro_2 0.9489 - custo 5.1928
# ÉPOCA 1982 finalizada: erro_0 9.9860 | erro_1 4.7078 | erro_2 0.9065 - custo 5.2001
# ÉPOCA 1983 finalizada: erro_0 9.9561 | erro_1 4.6656 | erro_2 0.9198 - custo 5.1805
# ÉPOCA 1984 finalizada: erro_0 9.8550 | erro_1 4.7108 | erro_2 0.9804 - custo 5.1821
# ÉPOCA 1985 finalizada: erro_0 10.0150 | erro_1 4.7051 | erro_2 0.9085 - custo 5.2095
# ÉPOCA 1986 finalizada: erro_0 9.9504 | erro_1 4.6876 | erro_2 0.9047 - custo 5.1809
# ÉPOCA 1987 finalizada: erro_0 9.8646 | erro_1 4.6317 | erro_2 0.8911 - custo 5.1291
# ÉPOCA 1988 finalizada: erro_0 9.8324 | erro_1 4.6158 | erro_2 0.9146 - custo 5.1209
# ÉPOCA 1989 finalizada: erro_0 10.0809 | erro_1 4.7915 | erro_2 1.0022 - custo 5.2915
# ÉPOCA 1990 finalizada: erro_0 9.7927 | erro_1 4.5979 | erro_2 0.8991 - custo 5.0966
# ÉPOCA 1991 finalizada: erro_0 10.1217 | erro_1 4.7214 | erro_2 0.9244 - custo 5.2558
# ÉPOCA 1992 finalizada: erro_0 9.8509 | erro_1 4.6125 | erro_2 0.9248 - custo 5.1294
# ÉPOCA 1993 finalizada: erro_0 10.5402 | erro_1 5.0316 | erro_2 0.9355 - custo 5.5024
# ÉPOCA 1994 finalizada: erro_0 10.0275 | erro_1 4.7288 | erro_2 0.9547 - custo 5.2370
# ÉPOCA 1995 finalizada: erro_0 10.3803 | erro_1 5.0177 | erro_2 0.9146 - custo 5.4375
# ÉPOCA 1996 finalizada: erro_0 11.8546 | erro_1 5.7922 | erro_2 1.1712 - custo 6.2727
# ÉPOCA 1997 finalizada: erro_0 9.6870 | erro_1 4.6244 | erro_2 1.0412 - custo 5.1175
# ÉPOCA 1998 finalizada: erro_0 10.0390 | erro_1 4.7001 | erro_2 0.8823 - custo 5.2072
# ÉPOCA 1999 finalizada: erro_0 9.6771 | erro_1 4.5732 | erro_2 0.9547 - custo 5.0683
# ÉPOCA 2000 finalizada: erro_0 9.5305 | erro_1 4.5016 | erro_2 0.9431 - custo 4.9917

# %% [markdown]
# ## Etapa 5: Avaliação do modelo

# %%
regressor.eval()
# Out:
# regressor_torch(
#   (dense0): Linear(in_features=61, out_features=32, bias=True)
#   (dense1): Linear(in_features=32, out_features=32, bias=True)
#   (activation): Sigmoid()
#   (output): Linear(in_features=32, out_features=3, bias=True)
# )

# %%
previsores = previsores.to(device)
previsoes = regressor.forward(previsores)

# %%
previsoes
# Out:
# tensor([[8.1886, 6.0122, 2.2543],
#         [8.3185, 6.1122, 2.2949],
#         [8.3563, 6.1413, 2.3067],
#         [3.4982, 2.4963, 0.6539],
#         [7.2181, 5.2709, 1.9461],
#         [8.2535, 6.0622, 2.2746],
#         [5.6370, 4.0803, 1.4218],
#         [8.3543, 6.1397, 2.3060],
#         [7.4240, 5.4274, 2.0123],
#         [3.2165, 2.2898, 0.5467],
#         [2.9437, 2.0905, 0.4414],
#         [8.1245, 5.9630, 2.2342],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9452, 2.0916, 0.4420],
#         [2.9449, 2.0914, 0.4419],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9438, 2.0906, 0.4414],
#         [7.2766, 5.3153, 1.9650],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9511, 2.0959, 0.4443],
#         [2.9437, 2.0905, 0.4414],
#         [2.9442, 2.0908, 0.4416],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [4.3140, 3.0972, 0.9561],
#         [2.9447, 2.0912, 0.4418],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [5.1211, 3.6957, 1.2436],
#         [2.9454, 2.0918, 0.4421],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9508, 2.0957, 0.4441],
#         [2.9465, 2.0926, 0.4425],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9447, 2.0912, 0.4418],
#         [5.6188, 4.0667, 1.4156],
#         [5.6034, 4.0552, 1.4103],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9441, 2.0908, 0.4415],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.3649, 2.3985, 0.6034],
#         [2.9440, 2.0907, 0.4415],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.8414, 2.7486, 0.7826],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [4.3069, 3.0920, 0.9536],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [8.2686, 6.0738, 2.2793],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.1056, 2.2087, 0.5040],
#         [2.9437, 2.0905, 0.4414],
#         [3.0128, 2.1409, 0.4682],
#         [2.9437, 2.0905, 0.4414],
#         [2.9542, 2.0981, 0.4455],
#         [2.9530, 2.0973, 0.4450],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [8.3559, 6.1410, 2.3066],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.0587, 2.1745, 0.4860],
#         [8.0347, 5.8941, 2.2060],
#         [2.9437, 2.0905, 0.4414],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [3.0793, 2.1895, 0.4939],
#         [2.9437, 2.0905, 0.4414],
#         [2.9470, 2.0929, 0.4427],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9839, 2.1198, 0.4570],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.3144, 2.3615, 0.5841],
#         [8.3481, 6.1349, 2.3041],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9438, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9641, 2.1054, 0.4493],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9456, 2.0919, 0.4421],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [7.5351, 5.5120, 2.0478],
#         [2.9579, 2.1008, 0.4469],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.8413, 2.4909, 0.0547],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.1118, 2.2133, 0.5064],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9471, 2.0930, 0.4427],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9443, 2.0909, 0.4416],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [6.2176, 4.5153, 1.6180],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [4.6303, 3.3313, 1.0701],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [3.0177, 2.1445, 0.4701],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9438, 2.0906, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414],
#         [2.9446, 2.0912, 0.4418],
#         [2.9437, 2.0905, 0.4414],
#         [2.9437, 2.0905, 0.4414]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
previsoes = previsoes.cpu().detach().numpy()

# %%
previsoes
# Out:
# array([[8.188602  , 6.0122366 , 2.2543166 ],
#        [8.318516  , 6.1121607 , 2.294905  ],
#        [8.356337  , 6.141283  , 2.3066933 ],
#        [3.4981523 , 2.4962566 , 0.6539022 ],
#        [7.2181354 , 5.2709002 , 1.9461365 ],
#        [8.25354   , 6.0621624 , 2.2746232 ],
#        [5.6369953 , 4.0802746 , 1.4218388 ],
#        [8.354265  , 6.139688  , 2.3060482 ],
#        [7.4240146 , 5.4274416 , 2.0122883 ],
#        [3.2164633 , 2.2897947 , 0.54665303],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [8.124472  , 5.9629703 , 2.234225  ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9452288 , 2.0916238 , 0.44198352],
#        [2.9449015 , 2.091385  , 0.44185638],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436724 , 2.0904884 , 0.44137898],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9438057 , 2.0905857 , 0.4414306 ],
#        [7.2766213 , 5.3153324 , 1.9649737 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9510956 , 2.0959027 , 0.44426182],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9441652 , 2.0908484 , 0.4415705 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [4.3139696 , 3.0972326 , 0.95613956],
#        [2.9446893 , 2.0912304 , 0.441774  ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [5.1210804 , 3.6956732 , 1.243555  ],
#        [2.9454284 , 2.0917695 , 0.4420611 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9507613 , 2.095659  , 0.44413197],
#        [2.946546  , 2.0925844 , 0.44249508],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9446948 , 2.0912344 , 0.4417761 ],
#        [5.6188073 , 4.0666866 , 1.4156202 ],
#        [5.603377  , 4.05516   , 1.4103408 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9440646 , 2.0907748 , 0.4415313 ],
#        [2.9436665 , 2.0904846 , 0.44137684],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.3648937 , 2.3985095 , 0.6033518 ],
#        [2.9439611 , 2.0906992 , 0.44149116],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904846 , 0.44137686],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436667 , 2.0904846 , 0.44137686],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.8414216 , 2.7486207 , 0.7825773 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436717 , 2.090488  , 0.44137865],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436674 , 2.090485  , 0.44137707],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [4.306921  , 3.0920231 , 0.95358044],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [8.268618  , 6.073762  , 2.2793329 ],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436667 , 2.0904846 , 0.4413769 ],
#        [2.943667  , 2.0904849 , 0.44137692],
#        [3.1055875 , 2.2087054 , 0.5040307 ],
#        [2.9436688 , 2.0904863 , 0.44137767],
#        [3.0127964 , 2.1409268 , 0.4681849 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.954157  , 2.098136  , 0.44545045],
#        [2.9530253 , 2.0973105 , 0.44501114],
#        [2.9436707 , 2.0904875 , 0.44137844],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436684 , 2.0904858 , 0.44137746],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436707 , 2.0904872 , 0.44137827],
#        [8.355925  , 6.140966  , 2.3065653 ],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436674 , 2.090485  , 0.44137707],
#        [2.943668  , 2.0904853 , 0.44137725],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [3.0587473 , 2.1744812 , 0.48595583],
#        [8.034692  , 5.8940687 , 2.2060363 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.0792508 , 2.1894596 , 0.4938727 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9469967 , 2.0929134 , 0.4426702 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.943667  , 2.0904849 , 0.44137692],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.943667  , 2.0904849 , 0.441377  ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.983882  , 2.1198227 , 0.4569826 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.3144438 , 2.3615386 , 0.58412695],
#        [8.348078  , 6.1349235 , 2.3041208 ],
#        [2.943748  , 2.0905435 , 0.44140837],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436667 , 2.0904846 , 0.4413769 ],
#        [2.9436665 , 2.0904846 , 0.44137686],
#        [2.943749  , 2.0905442 , 0.44140872],
#        [2.943702  , 2.0905104 , 0.44139048],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9437518 , 2.0905466 , 0.4414098 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904846 , 0.44137686],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9641094 , 2.1053963 , 0.44931343],
#        [2.943679  , 2.0904937 , 0.4413816 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.945602  , 2.091896  , 0.44212848],
#        [2.943672  , 2.0904884 , 0.4413788 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436727 , 2.090489  , 0.44137913],
#        [7.5350575 , 5.5120325 , 2.0477881 ],
#        [2.9578671 , 2.1008425 , 0.44689083],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904846 , 0.44137684],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436731 , 2.0904891 , 0.44137925],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.8413198 , 2.4909205 , 0.0547204 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436677 , 2.0904853 , 0.4413772 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.1118193 , 2.2132602 , 0.5064322 ],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904846 , 0.44137684],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.943672  , 2.0904884 , 0.4413788 ],
#        [2.943667  , 2.0904846 , 0.44137692],
#        [2.9436665 , 2.0904846 , 0.44137684],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9471426 , 2.0930197 , 0.44272682],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9442716 , 2.0909257 , 0.44161168],
#        [2.9436665 , 2.0904846 , 0.44137684],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [6.217633  , 4.5152736 , 1.6179776 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [4.630327  , 3.331347  , 1.0701036 ],
#        [2.9436698 , 2.0904868 , 0.44137803],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [3.0176806 , 2.1444924 , 0.4700756 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.943668  , 2.0904853 , 0.44137725],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.943667  , 2.0904846 , 0.4413769 ],
#        [2.9436898 , 2.0905015 , 0.44138587],
#        [2.9436665 , 2.0904844 , 0.4413768 ],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436712 , 2.0904877 , 0.44137844],
#        [2.9437647 , 2.090556  , 0.44141495],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9446394 , 2.0911937 , 0.44175452],
#        [2.9436665 , 2.0904844 , 0.44137675],
#        [2.9436665 , 2.0904844 , 0.44137675]], dtype=float32)

# %%
previsoes.mean(axis = 0)
# Out:
# array([3.2983274, 2.3657193, 0.558011 ], dtype=float32)

# %%
vendas.mean(axis = 0)
# Out:
# tensor([3.2838, 2.3505, 0.5862])

# %%
fig, ax = plt.subplots(1, 3, figsize=(10,5))
for i in range(3):
  ax[i].plot(vendas[:, i])
  ax[i].plot(previsoes[:, i])
  ax[i].legend(['Valores reais', 'Previsões'])
  ax[i].set_title(base.columns[4 + i])
